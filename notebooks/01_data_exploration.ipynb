# %% [markdown]
# # 01 — Exploratory Data Analysis: Polymarket
#
# ---
#
# ### Objetivo
# Explorar la estructura, calidad y patrones ocultos en los datos de Polymarket para informar
# el diseño de features y la viabilidad del modelo ML.
#
# ### Estructura del EDA
#
# | Sección | Enfoque |
# |---|---|
# | **1. Data Acquisition** | Descarga y cache de mercados activos + resueltos |
# | **2. Data Quality Audit** | Missings, tipos, anomalías, integridad |
# | **3. Univariate Analysis** | Distribuciones de precio, volumen, liquidez, spread |
# | **4. Bivariate & Multivariate** | Correlaciones, scatter matrix, interacciones |
# | **5. Market Efficiency Analysis** | Calibración de precios — ¿los precios reflejan la realidad? |
# | **6. Temporal Patterns** | Ciclo de vida de mercados, estacionalidad, decay |
# | **7. Category Intelligence** | Análisis por categoría: volumen, accuracy, spreads |
# | **8. Outlier & Anomaly Detection** | Mercados atípicos, oportunidades potenciales |
# | **9. Label Viability** | Distribución de labels, class imbalance, sesgo de resolución |
# | **10. Key Findings** | Resumen de hallazgos e hipótesis para el modelo |

# %%
import sys
sys.path.insert(0, '..')

import json
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from pathlib import Path
from scipy import stats

from src.data.client import PolymarketDataClient
from src.data.preprocessing import (
    preprocess_markets, compute_label, get_snapshot_price,
)

warnings.filterwarnings('ignore', category=FutureWarning)

# ── Style ──
sns.set_theme(style='whitegrid', font_scale=1.05)
plt.rcParams.update({
    'figure.figsize': (14, 8),
    'figure.dpi': 120,
    'axes.titlesize': 13,
    'axes.titleweight': 'bold',
})

PALETTE = ['#2196F3', '#FF5722', '#4CAF50', '#9C27B0', '#FF9800', '#607D8B']
raw_dir = Path('../data/raw')
fig_dir = Path('../figures')
raw_dir.mkdir(parents=True, exist_ok=True)
fig_dir.mkdir(parents=True, exist_ok=True)

print('Setup completo.')
# Out:
# Setup completo.

# %% [markdown]
# ---
# ## 1. Data Acquisition

# %%
client = PolymarketDataClient(rate_limit_delay=0.2)

# ── Descarga (o carga desde cache) ──
active_path = raw_dir / 'active_markets.json'
resolved_path = raw_dir / 'resolved_markets.json'
price_hist_path = raw_dir / 'price_histories.json'

# 1. Mercados
if active_path.exists() and resolved_path.exists():
    print('Cargando mercados desde cache local...')
    with open(active_path) as f:
        active_parsed = json.load(f)
    with open(resolved_path) as f:
        resolved_parsed = json.load(f)
else:
    print('Descargando mercados activos...')
    raw_active = client.get_all_active_markets(max_markets=1000)
    active_parsed = [client.parse_market(m) for m in raw_active]

    print('Descargando mercados resueltos...')
    raw_resolved = client.get_all_resolved_markets(max_markets=2000)
    resolved_parsed = [client.parse_market(m) for m in raw_resolved]

    with open(active_path, 'w') as f:
        json.dump(active_parsed, f, default=str, indent=2)
    with open(resolved_path, 'w') as f:
        json.dump(resolved_parsed, f, default=str, indent=2)

print(f'Mercados activos:   {len(active_parsed):,}')
print(f'Mercados resueltos: {len(resolved_parsed):,}')

# ── Sanity check: verificar que la API de price history funciona ──
test_market = next((m for m in resolved_parsed if m.get('clobTokenIds')), None)
if test_market:
    token = test_market['clobTokenIds'][0]
    try:
        test_hist = client.get_price_history(token, interval='all', fidelity=60)
        print(f'\nAPI check OK: market {test_market["id"]} -> {len(test_hist)} price points')
    except Exception as e:
        print(f'\nAPI check FAILED: {type(e).__name__}: {e}')
        print('Revisa que el kernel se haya reiniciado para cargar el client.py actualizado.')

# 2. Price Histories — serie temporal por mercado
# Estructura: {market_id: [{t: unix_ts, p: price}, ...]}
if price_hist_path.exists():
    print('\nCargando price histories desde cache...')
    with open(price_hist_path) as f:
        price_histories = json.load(f)
else:
    from tqdm.notebook import tqdm
    print('\nDescargando price histories...')
    price_histories = {}
    errors = 0
    empty = 0
    all_markets = resolved_parsed + active_parsed

    for m in tqdm(all_markets, desc='Price histories'):
        token_ids = m.get('clobTokenIds', [])
        if isinstance(token_ids, str):
            try:
                token_ids = json.loads(token_ids)
            except Exception:
                token_ids = []
        if not token_ids:
            continue
        market_id = str(m.get('id', ''))
        try:
            history = client.get_price_history(token_ids[0], interval='all', fidelity=60)
            if history:
                price_histories[market_id] = history
            else:
                empty += 1
        except Exception as e:
            errors += 1
            if errors <= 3:
                print(f'  Error #{errors}: {type(e).__name__}: {e}')

    with open(price_hist_path, 'w') as f:
        json.dump(price_histories, f)
    print(f'Descarga completa: {len(price_histories)} con historial, {empty} vacios, {errors} errores')

print(f'Price histories: {len(price_histories):,} mercados con historial')
# Out:
# Cargando mercados desde cache local...
# Mercados activos:   1,000
# Mercados resueltos: 2,000
#
# API check OK: market 1361753 -> 96 price points
#
# Cargando price histories desde cache...
# Price histories: 1,739 mercados con historial

# %%
# Preprocesar
df_act = preprocess_markets(str(active_path))
df_res = preprocess_markets(str(resolved_path))

# ── Extraer snapshot prices reales del historial ──
# Para cada mercado resuelto, obtenemos el precio N dias antes de la resolucion.
# Esto nos da el precio PRE-resolucion, no el precio final (0 o 1).
SNAPSHOT_OFFSET_DAYS = 7

def extract_snapshot_from_history(market, histories, offset_days=7):
    """Extrae precio snapshot de la serie temporal."""
    market_id = str(market.get('id', ''))
    history = histories.get(market_id, [])
    if not history:
        return np.nan
    end_str = market.get('endDate', '')
    if not end_str:
        return np.nan
    try:
        end_ts = pd.to_datetime(end_str, utc=True).timestamp()
    except Exception:
        return np.nan
    target_ts = end_ts - (offset_days * 86400)
    # Buscar punto mas cercano anterior al target
    best_price, best_delta = np.nan, float('inf')
    for point in history:
        t = point.get('t', 0)
        p = point.get('p', 0)
        if t <= target_ts:
            delta = target_ts - t
            if delta < best_delta:
                best_delta = delta
                best_price = float(p)
    return best_price

# Aplicar a mercados resueltos
snapshot_prices = []
for m in resolved_parsed:
    snapshot_prices.append(extract_snapshot_from_history(m, price_histories, SNAPSHOT_OFFSET_DAYS))
df_res['snapshot_price'] = snapshot_prices[:len(df_res)]

n_with_snapshot = df_res['snapshot_price'].notna().sum()
print(f'Active shape:   {df_act.shape}')
print(f'Resolved shape: {df_res.shape}')
print(f'Mercados resueltos con snapshot price: {n_with_snapshot}/{len(df_res)}')
print(f'  (precio {SNAPSHOT_OFFSET_DAYS} dias antes de resolucion, extraido del historial real)')

df_res[['question', 'price_yes', 'snapshot_price', 'resolution']].head(10)

# %% [markdown]
# ---
# ## 2. Data Quality Audit
#
# Antes de cualquier análisis, auditamos la integridad de los datos.

# %%
def quality_report(df, name='Dataset'):
    """Genera un reporte de calidad de datos compacto."""
    n = len(df)

    # nunique seguro: algunas columnas tienen listas (unhashable)
    nunique = {}
    for col in df.columns:
        try:
            nunique[col] = df[col].nunique()
        except TypeError:
            nunique[col] = np.nan

    report = pd.DataFrame({
        'dtype': df.dtypes,
        'non_null': df.count(),
        'null_pct': (df.isnull().sum() / n * 100).round(1),
        'nunique': pd.Series(nunique),
    })
    if n > 0:
        sample_vals = []
        for col in df.columns:
            try:
                sample_vals.append(str(df[col].iloc[0]))
            except Exception:
                sample_vals.append('N/A')
        report['sample'] = sample_vals

    print(f'\n{"="*60}')
    print(f' {name} — {n:,} rows x {len(df.columns)} columns')
    print(f'{"="*60}')

    # Columnas con >30% nulls
    high_null = report[report['null_pct'] > 30]
    if not high_null.empty:
        print(f'\n  Columnas con >30% nulls:')
        for col, row in high_null.iterrows():
            print(f'    {col}: {row["null_pct"]}%')
    else:
        print('\n  Sin columnas con >30% nulls.')

    # Columnas constantes
    constants = report[report['nunique'] <= 1].index.tolist()
    if constants:
        print(f'  Columnas constantes (0 varianza): {constants}')

    return report

q_active = quality_report(df_act, 'Mercados Activos')
q_resolved = quality_report(df_res, 'Mercados Resueltos')

# %%
# ── Heatmap de missings ──
key_cols = [
    'price_yes', 'price_no', 'volume', 'volume24hr', 'liquidity',
    'bestBid', 'bestAsk', 'spread', 'endDate', 'createdAt',
    'days_to_resolution', 'market_age_days',
]
existing_cols = [c for c in key_cols if c in df_act.columns]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
for ax, df, title in [(axes[0], df_act, 'Activos'), (axes[1], df_res, 'Resueltos')]:
    cols = [c for c in existing_cols if c in df.columns]
    null_pct = df[cols].isnull().mean().sort_values(ascending=True) * 100
    bars = ax.barh(null_pct.index, null_pct.values, color=PALETTE[0], alpha=0.8)
    ax.set_xlabel('% Nulls')
    ax.set_title(f'Datos Faltantes — {title}')
    ax.set_xlim(0, max(100, null_pct.max() + 5))
    for bar, val in zip(bars, null_pct.values):
        if val > 0:
            ax.text(val + 0.5, bar.get_y() + bar.get_height()/2,
                    f'{val:.1f}%', va='center', fontsize=8)

plt.tight_layout()
plt.savefig(fig_dir / '01_missing_data.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## 3. Univariate Analysis
#
# Distribuciones individuales de las variables clave. Buscamos:
# - Forma de la distribución (normal, power-law, bimodal)
# - Outliers
# - Concentración en extremos (precios cerca de 0 o 1)

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Precio Yes — ¿bimodal? ¿concentrado en extremos?
ax = axes[0, 0]
prices = df_act['price_yes'].dropna()
sns.histplot(prices, bins=60, kde=True, ax=ax, color=PALETTE[0], alpha=0.7)
ax.axvline(prices.median(), color='red', ls='--', lw=1.2, label=f'Mediana: {prices.median():.2f}')
ax.set_title('Precio "Yes" — Mercados Activos')
ax.set_xlabel('Precio (probabilidad implícita)')
ax.legend(fontsize=9)

# 2. Volumen 24h (log scale por power-law)
ax = axes[0, 1]
vol = df_act['volume24hr'].replace(0, np.nan).dropna()
if len(vol) > 0:
    sns.histplot(np.log10(vol + 1), bins=50, ax=ax, color=PALETTE[1], alpha=0.7, kde=True)
ax.set_title('Volumen 24h (log10)')
ax.set_xlabel('log10(volume24hr + 1)')

# 3. Liquidez (log scale)
ax = axes[0, 2]
liq = df_act['liquidity'].replace(0, np.nan).dropna()
if len(liq) > 0:
    sns.histplot(np.log10(liq + 1), bins=50, ax=ax, color=PALETTE[2], alpha=0.7, kde=True)
ax.set_title('Liquidez (log10)')
ax.set_xlabel('log10(liquidity + 1)')

# 4. Spread — cola larga esperada
ax = axes[1, 0]
spr = df_act['spread'].dropna()
spr = spr[spr > 0]
if len(spr) > 0:
    sns.histplot(spr.clip(upper=spr.quantile(0.95)), bins=50, ax=ax, color=PALETTE[3], alpha=0.7, kde=True)
ax.set_title('Spread Bid-Ask (truncado p95)')
ax.set_xlabel('Spread')

# 5. Días a resolución
ax = axes[1, 1]
days = df_act['days_to_resolution'].dropna()
if len(days) > 0:
    sns.histplot(days.clip(upper=365), bins=60, ax=ax, color=PALETTE[4], alpha=0.7, kde=True)
ax.set_title('Días a Resolución')
ax.set_xlabel('Días restantes')

# 6. Edad del mercado
ax = axes[1, 2]
age = df_act['market_age_days'].dropna()
if len(age) > 0:
    sns.histplot(age.clip(upper=age.quantile(0.95)), bins=50, ax=ax, color=PALETTE[5], alpha=0.7, kde=True)
ax.set_title('Edad del Mercado (días)')
ax.set_xlabel('Días desde creación')

plt.suptitle('Distribuciones Univariadas — Mercados Activos', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_univariate_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Box plots comparativos: activos vs resueltos ──
compare_cols = ['price_yes', 'volume24hr', 'liquidity', 'spread']
compare_cols = [c for c in compare_cols if c in df_act.columns and c in df_res.columns]

fig, axes = plt.subplots(1, len(compare_cols), figsize=(4 * len(compare_cols), 5))
if len(compare_cols) == 1:
    axes = [axes]

for ax, col in zip(axes, compare_cols):
    data = pd.DataFrame({
        'value': pd.concat([df_act[col], df_res[col]], ignore_index=True),
        'set': ['Activos'] * len(df_act) + ['Resueltos'] * len(df_res),
    })
    cap = data['value'].quantile(0.95)
    data['value'] = data['value'].clip(upper=cap)
    sns.boxplot(data=data, x='set', y='value', ax=ax,
                palette=[PALETTE[0], PALETTE[1]], width=0.5)
    ax.set_title(col)
    ax.set_xlabel('')

plt.suptitle('Activos vs Resueltos — Comparación de Distribuciones (truncadas p95)',
             fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_active_vs_resolved_box.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways del Analisis Univariado
#
# | Variable | Hallazgo | Implicacion para el modelo |
# |---|---|---|
# | **Precio Yes** | Distribucion muy sesgada a la izquierda (mediana ~0.02). La mayoria de mercados son longshots con baja probabilidad implicita. | El dataset esta dominado por eventos improbables. El modelo debera aprender a distinguir entre longshots con y sin valor real. |
# | **Volumen 24h** | Log-normal (power law). Centro ~$30K, con alta varianza. | Suficiente actividad para que los precios contengan informacion, pero hay mercados con muy poco volumen donde los precios pueden ser menos confiables. |
# | **Liquidez** | Log-normal, centrada en ~$100K. | Buena liquidez general reduce riesgo de slippage al operar. |
# | **Spread** | Concentrado en valores muy bajos (<0.005), con outliers aislados. | Mercado razonablemente eficiente en general. Los spreads anomalamente altos podrian senalar ineficiencias explotables. |
# | **Dias a Resolucion** | Gran concentracion en 0-50 dias. | Mercados proximos a resolver ya tienen precios "decididos". El alpha probable esta en mercados a mediano plazo (30-150 dias). |
# | **Edad del Mercado** | Distribucion irregular con picos — mercados se crean en oleadas (eventos: elecciones, Fed, etc). | Existe estacionalidad en la creacion de mercados. |
#
# **Box Plots — Activos vs Resueltos:**
# - **price_yes**: Los activos muestran precios bajos (mediana ~0.1); los resueltos convergen a ~0 (mayoria resolvio "No").
# - **volume24hr**: Activos tienen mucho mas volumen diario (logico — los resueltos ya no se operan).
# - **liquidity**: Mas liquidez en activos.
# - **spread**: Activos tienen spreads mas amplios; los resueltos convergieron a spreads minimos.
#
# **Conclusion general:** El mercado es bastante eficiente (spreads bajos), pero hay nichos de ineficiencia potencial en mercados con **baja liquidez, alto spread y probabilidades intermedias** — esos son los candidatos donde el modelo podria encontrar alpha.

# %% [markdown]
# ---
# ## 4. Bivariate & Multivariate Analysis
#
# Relaciones entre variables clave. Buscamos:
# - Correlaciones fuertes (redundancia en features)
# - Relaciones no lineales
# - Clusters naturales en los datos

# %%
# ── Matriz de correlación ──
corr_cols = [
    'price_yes', 'spread', 'volume24hr', 'volume', 'liquidity',
    'volume_liquidity_ratio', 'days_to_resolution', 'market_age_days',
]
corr_cols = [c for c in corr_cols if c in df_act.columns]

corr = df_act[corr_cols].corr()

fig, ax = plt.subplots(figsize=(10, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(
    corr, mask=mask, annot=True, fmt='.2f', cmap='RdBu_r',
    center=0, square=True, linewidths=0.5, ax=ax,
    cbar_kws={'shrink': 0.8},
)
ax.set_title('Correlación entre Features Numéricas')
plt.tight_layout()
plt.savefig(fig_dir / '01_correlation_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Pares con correlación alta
high_corr = []
for i in range(len(corr.columns)):
    for j in range(i+1, len(corr.columns)):
        val = corr.iloc[i, j]
        if abs(val) > 0.5:
            high_corr.append((corr.columns[i], corr.columns[j], val))

if high_corr:
    print('Pares con |corr| > 0.5:')
    for a, b, v in sorted(high_corr, key=lambda x: -abs(x[2])):
        print(f'  {a} <-> {b}: {v:.3f}')

# %%
# ── Scatter: Precio vs Spread (hipótesis: spreads altos = mercados ineficientes) ──
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Precio vs Spread
ax = axes[0]
x = df_act['price_yes'].dropna()
y = df_act['spread'].dropna()
mask = x.index.intersection(y.index)
ax.scatter(x.loc[mask], y.loc[mask].clip(upper=0.15), alpha=0.3, s=12, c=PALETTE[0])
ax.set_xlabel('Precio Yes')
ax.set_ylabel('Spread')
ax.set_title('Precio vs Spread\n(spread alto = menos eficiente)')

# Volumen vs Spread (en log)
ax = axes[1]
vol_data = df_act[['volume24hr', 'spread']].dropna()
vol_data = vol_data[vol_data['volume24hr'] > 0]
ax.scatter(
    np.log10(vol_data['volume24hr'] + 1),
    vol_data['spread'].clip(upper=0.15),
    alpha=0.3, s=12, c=PALETTE[1]
)
ax.set_xlabel('log10(Volume 24h)')
ax.set_ylabel('Spread')
ax.set_title('Volumen vs Spread\n(alto volumen debería reducir spread)')

# Liquidez vs Edad
ax = axes[2]
la_data = df_act[['liquidity', 'market_age_days']].dropna()
la_data = la_data[la_data['liquidity'] > 0]
ax.scatter(
    la_data['market_age_days'].clip(upper=la_data['market_age_days'].quantile(0.95)),
    np.log10(la_data['liquidity'] + 1),
    alpha=0.3, s=12, c=PALETTE[2]
)
ax.set_xlabel('Edad del mercado (días)')
ax.set_ylabel('log10(Liquidez)')
ax.set_title('Edad vs Liquidez\n(mercados maduros acumulan liquidez)')

plt.suptitle('Relaciones Bivariadas Clave', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_bivariate_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Bubble chart: Precio vs Volumen, tamaño = liquidez, color = spread ──
fig, ax = plt.subplots(figsize=(14, 8))

plot_data = df_act[['price_yes', 'volume24hr', 'liquidity', 'spread']].dropna()
plot_data = plot_data[(plot_data['volume24hr'] > 0) & (plot_data['liquidity'] > 0)]

if len(plot_data) > 0:
    sizes = np.clip(plot_data['liquidity'] / plot_data['liquidity'].quantile(0.9) * 100, 10, 500)
    scatter = ax.scatter(
        plot_data['price_yes'],
        np.log10(plot_data['volume24hr'] + 1),
        s=sizes,
        c=plot_data['spread'].clip(upper=plot_data['spread'].quantile(0.95)),
        cmap='RdYlGn_r',
        alpha=0.6,
        edgecolors='gray', linewidths=0.3,
    )
    plt.colorbar(scatter, label='Spread', shrink=0.8)
    ax.set_xlabel('Precio Yes')
    ax.set_ylabel('log10(Volumen 24h)')
    ax.set_title('Mapa de Mercados: Precio x Volumen x Liquidez x Spread\n'
                 '(tamaño = liquidez, color = spread)')

plt.tight_layout()
plt.savefig(fig_dir / '01_bubble_chart.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways del Analisis Bivariado y Multivariado
#
# **Matriz de Correlacion:**
# - **volume <-> liquidity (0.71):** Alta redundancia — estos features capturan informacion similar. Considerar usar solo uno o crear un feature combinado.
# - **spread <-> volume_liquidity_ratio (0.69):** El ratio volumen/liquidez se comporta de forma muy similar al spread. Ambos miden "actividad relativa" del mercado.
# - **days_to_resolution <-> market_age_days (0.60):** Mercados mas viejos tienden a tener mas dias restantes — probablemente mercados de largo plazo.
# - **volume24hr es casi independiente** de todas las demas variables — captura informacion unica sobre actividad *reciente* que no esta en volume total ni liquidez.
# - **price_yes** tiene correlaciones negativas debiles con edad (-0.34) y liquidez (-0.24) — los mercados maduros y liquidos tienden a tener precios mas bajos (mas longshots).
#
# **Scatter Plots:**
# - **Precio vs Spread:** La mayoria de mercados tienen spread bajo independientemente del precio, pero existen outliers con spread alto en todo el rango de precios — estos son candidatos a ineficiencia.
# - **Volumen vs Spread:** Mayor volumen se asocia con spreads mas bajos (esperado). Los mercados de bajo volumen con spread alto son los mas ineficientes.
# - **Edad vs Liquidez:** Tendencia positiva clara — mercados maduros acumulan mas liquidez con el tiempo.
#
# **Bubble Chart (4 dimensiones):**
# - Cluster denso en precios bajos (0-0.1) con alto volumen y spread bajo (verde) — estos son los longshots liquidos y eficientes.
# - Puntos dispersos a precios medios-altos con spread elevado (tonos rojos/amarillos) — **zona de oportunidad potencial** para el modelo.
#
# **Implicaciones para feature engineering:**
# - Evaluar si `volume` y `liquidity` aportan informacion distinta o si conviene reducir a un solo feature.
# - `volume24hr` es un feature valioso e independiente — conservar.
# - El spread es un **indicador directo de ineficiencia** y deberia ser un feature importante para el modelo.

# %% [markdown]
# ---
# ## 5. Market Efficiency Analysis (Calibration)
#
# **Pregunta central:** ¿los precios de Polymarket están bien calibrados?
#
# Si un mercado tiene precio 0.70, ¿realmente resuelve "Yes" ~70% del tiempo?
#
# - Si los precios están perfectamente calibrados → no hay alpha, el modelo no tiene ventaja.
# - Si hay desviaciones sistemáticas → oportunidad para el modelo.
#
# Esto es **la prueba de fuego** de todo el proyecto.

# %%
# ── Calibration curve: precio predicho vs frecuencia real de "Yes" ──
# Ahora usamos snapshot_price (precio REAL N dias antes de resolucion)
# en lugar de outcomePrices (que es 0 o 1 post-resolucion).

res_cal = df_res[df_res['snapshot_price'].notna() & df_res['resolution'].notna()].copy()
res_cal['resolved_yes'] = res_cal['resolution'].str.strip().str.lower() == 'yes'

# Filtrar precios razonables
res_cal = res_cal[
    (res_cal['snapshot_price'] > 0.02) & (res_cal['snapshot_price'] < 0.98)
]

print(f'Mercados con snapshot price valido para calibracion: {len(res_cal)}')

# Binning adaptativo
n_bins = min(10, max(3, len(res_cal) // 20))
res_cal['price_bin'] = pd.cut(
    res_cal['snapshot_price'], bins=n_bins, labels=False
)

calibration = res_cal.groupby('price_bin').agg(
    mean_price=('snapshot_price', 'mean'),
    actual_yes_rate=('resolved_yes', 'mean'),
    count=('resolved_yes', 'count'),
).dropna()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Calibration curve
ax = axes[0]
ax.plot([0, 1], [0, 1], 'k--', alpha=0.4, label='Calibracion perfecta')
ax.scatter(
    calibration['mean_price'], calibration['actual_yes_rate'],
    s=calibration['count'] * 2, c=PALETTE[0], alpha=0.8,
    edgecolors='navy', linewidths=1, zorder=5,
)
ax.plot(calibration['mean_price'], calibration['actual_yes_rate'],
        '-', color=PALETTE[0], alpha=0.5)
ax.set_xlabel('Snapshot Price (Probabilidad Implicita, {} dias antes)'.format(SNAPSHOT_OFFSET_DAYS))
ax.set_ylabel('Tasa Real de Resolucion "Yes"')
ax.set_title('Curva de Calibracion del Mercado\n(tamano = N mercados en bin)')
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_aspect('equal')

# Desviacion de calibracion
ax = axes[1]
deviation = calibration['actual_yes_rate'] - calibration['mean_price']
colors = ['#4CAF50' if d >= 0 else '#FF5722' for d in deviation]
ax.bar(range(len(deviation)), deviation, color=colors, alpha=0.8)
ax.axhline(0, color='black', lw=0.8)
ax.set_xticks(range(len(calibration)))
ax.set_xticklabels([f'{p:.2f}' for p in calibration['mean_price']], rotation=45)
ax.set_xlabel('Snapshot Price Promedio del Bin')
ax.set_ylabel('Desviacion (Real - Precio)')
ax.set_title('Desviacion de Calibracion por Bin\n'
             '(verde = mercado subestima, rojo = sobreestima)')

plt.suptitle('Eficiencia del Mercado de Polymarket', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_calibration_curve.png', dpi=150, bbox_inches='tight')
plt.show()

# Brier Score
brier = np.mean((res_cal['snapshot_price'] - res_cal['resolved_yes'].astype(float)) ** 2)
print(f'\nBrier Score del mercado (snapshot {SNAPSHOT_OFFSET_DAYS}d antes): {brier:.4f}')
print(f'  (0 = perfecto, 0.25 = aleatorio, <0.1 = bien calibrado)')
print(f'  Interpretacion: {"bien calibrado" if brier < 0.15 else "hay espacio para alpha"}')

# %%
# ── Analisis de Overconfidence/Underconfidence ──
# Favorite-longshot bias: los mercados sobrevaloran eventos de baja probabilidad?

fig, ax = plt.subplots(figsize=(12, 6))

bins = np.linspace(0, 1, 21)
res_cal['price_bin_fine'] = pd.cut(
    res_cal['snapshot_price'], bins=bins, labels=False
)

cal_fine = res_cal.groupby('price_bin_fine').agg(
    mean_price=('snapshot_price', 'mean'),
    actual_rate=('resolved_yes', 'mean'),
    n=('resolved_yes', 'count'),
).dropna()

cal_fine = cal_fine[cal_fine['n'] >= 3]  # Solo bins con suficientes datos

ax.fill_between(
    cal_fine['mean_price'],
    cal_fine['mean_price'],
    cal_fine['actual_rate'],
    alpha=0.2, color='red', label='Desviacion'
)
ax.plot(cal_fine['mean_price'], cal_fine['actual_rate'],
        'o-', color=PALETTE[0], markersize=6, label='Tasa real')
ax.plot([0, 1], [0, 1], 'k--', alpha=0.4, label='Calibrado')

ax.set_xlabel('Snapshot Price (Probabilidad Implicita)')
ax.set_ylabel('Tasa Real de Resolucion "Yes"')
ax.set_title('Favorite-Longshot Bias en Polymarket\n'
             '(linea azul encima de diagonal = longshots infravalorados)')
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

plt.tight_layout()
plt.savefig(fig_dir / '01_favorite_longshot_bias.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways del Analisis de Eficiencia del Mercado
#
# **Calibracion (Curva + Desviacion):**
# - El mercado de Polymarket **sobreestima probabilidades** en el rango bajo-medio: mercados con snapshot price ~0.40 resuelven "Yes" significativamente menos del 40% del tiempo.
# - Solo en precios muy altos (~0.97) el mercado subestima ligeramente (barra verde) — los casi-seguros si cumplen.
# - **Pocos bins** en la calibracion (3): esto se debe a que la mayoria de mercados ya tienen precios extremos (~0 o ~1) a 7 dias de resolver. Solo una fraccion tenia incertidumbre real en el snapshot.
#
# **Favorite-Longshot Bias:**
# - **Resultado contrario al esperado**: los longshots (precios bajos) NO estan infravalorados — estan **sobrevalorados**. La linea azul esta por debajo de la diagonal en casi todo el rango.
# - Esto significa que comprar longshots al precio de mercado es una estrategia perdedora en promedio.
# - Solo los favoritos fuertes (precio > 0.90) tienen una tasa de resolucion que iguala o supera su precio.
#
# **Implicaciones para el modelo:**
# - Hay espacio para alpha, pero **no en longshots** — el mercado ya los sobrevalora.
# - La oportunidad esta en identificar mercados de **rango medio (0.20-0.80)** donde el mercado esta mal calibrado.
# - El modelo deberia aprender a **ajustar hacia abajo** las probabilidades del mercado en la mayoria de los casos, y detectar los pocos mercados donde el ajuste deberia ser hacia arriba.
# - **Limitacion importante**: solo ~N mercados tenian snapshot prices en rango util (0.02-0.98). Con mas datos historicos, la calibracion seria mas robusta.

# %% [markdown]
# ---
# ## 6. Temporal Patterns
#
# ¿Cómo evoluciona la actividad de mercados en el tiempo? ¿Hay estacionalidad?

# %%
# ── Timeline de creación de mercados ──
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Mercados creados por mes
ax = axes[0, 0]
if 'createdAt' in df_res.columns:
    created = df_res['createdAt'].dropna()
    monthly = created.dt.to_period('M').value_counts().sort_index()
    monthly.index = monthly.index.astype(str)
    if len(monthly) > 24:  # Truncar si hay demasiados meses
        monthly = monthly.iloc[-24:]
    monthly.plot.bar(ax=ax, color=PALETTE[0], alpha=0.8, width=0.8)
    ax.set_title('Mercados Creados por Mes')
    ax.set_ylabel('Cantidad')
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=7)

# 2. Relación entre edad y volumen (¿los mercados jóvenes tienen más hype?)
ax = axes[0, 1]
age_vol = df_act[['market_age_days', 'volume24hr']].dropna()
age_vol = age_vol[age_vol['volume24hr'] > 0]
if len(age_vol) > 10:
    age_bins = pd.cut(age_vol['market_age_days'], bins=10)
    grouped = age_vol.groupby(age_bins, observed=True)['volume24hr'].median()
    grouped.plot.bar(ax=ax, color=PALETTE[4], alpha=0.8)
    ax.set_title('Volumen 24h Mediano por Edad del Mercado')
    ax.set_ylabel('Mediana Vol24h ($)')
    ax.set_xlabel('Edad (días)')
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=8)

# 3. Distribución de time-to-resolution
ax = axes[1, 0]
if 'endDate' in df_res.columns and 'createdAt' in df_res.columns:
    lifespan = (df_res['endDate'] - df_res['createdAt']).dt.total_seconds() / 86400
    lifespan = lifespan.dropna()
    lifespan = lifespan[(lifespan > 0) & (lifespan < 365)]
    if len(lifespan) > 0:
        sns.histplot(lifespan, bins=50, ax=ax, color=PALETTE[2], alpha=0.7, kde=True)
        ax.axvline(lifespan.median(), color='red', ls='--',
                   label=f'Mediana: {lifespan.median():.0f} días')
        ax.legend()
ax.set_title('Ciclo de Vida: Duración Total de Mercados Resueltos')
ax.set_xlabel('Días (creación a resolución)')

# 4. ¿Los mercados cercanos a resolución tienen spreads más bajos?
ax = axes[1, 1]
ds = df_act[['days_to_resolution', 'spread']].dropna()
ds = ds[ds['spread'] > 0]
if len(ds) > 10:
    time_bins = pd.cut(ds['days_to_resolution'], bins=8)
    grouped = ds.groupby(time_bins, observed=True)['spread'].median()
    grouped.plot.bar(ax=ax, color=PALETTE[3], alpha=0.8)
    ax.set_title('Spread Mediano por Tiempo a Resolución\n'
                 '(cercanos a resolución deberían tener menor spread)')
    ax.set_ylabel('Spread mediano')
    ax.set_xlabel('Días a resolución')
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right', fontsize=8)

plt.suptitle('Patrones Temporales', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_temporal_patterns.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways de Patrones Temporales
#
# **Mercados Creados por Mes:**
# - Crecimiento explosivo en la creacion de mercados a partir de mediados de 2025, con pico en enero 2026.
# - La plataforma esta en fase de expansion acelerada — los datos mas recientes dominan el dataset.
# - Implicacion: el modelo se entrenara mayormente con mercados recientes, lo cual es bueno (relevancia) pero limita la diversidad historica.
#
# **Volumen 24h por Edad del Mercado:**
# - Los mercados mas nuevos (~0-35 dias) tienen volumen moderado.
# - Hay un pico masivo en los mercados mas viejos (>300 dias) — estos son mercados de largo plazo con mucho interes (ej. elecciones, macro).
# - El "valle" en mercados de edad media sugiere que la atencion del mercado se concentra en lo nuevo y lo historicamente importante.
#
# **Ciclo de Vida (Duracion Total):**
# - Mediana de 169 dias de creacion a resolucion.
# - Distribucion multimodal: picos en ~50-100 dias (mercados de corto plazo) y ~300-365 dias (mercados anuales/de largo plazo).
# - Esto confirma que hay dos "tipos" de mercados con dinamicas distintas que el modelo deberia tratar diferente.
#
# **Spread por Tiempo a Resolucion:**
# - Resultado contraintuitivo: los mercados en el rango ~170-370 dias tienen el **spread mas alto** (~0.01), no los cercanos a resolver.
# - Los mercados muy cercanos a resolucion (<123 dias) y los muy lejanos (>370 dias) tienen spreads bajos.
# - Interpretacion: los mercados de mediano plazo son los menos liquidos/eficientes — **zona de oportunidad potencial** para el modelo.
#
# **Implicaciones para el modelo:**
# - `days_to_resolution` y `market_age_days` son features informativos — capturan distintos regimenes de comportamiento.
# - Los mercados de **mediano plazo (100-370 dias)** combinan spreads altos con incertidumbre real — candidatos ideales para scoring.
# - Considerar segmentar el modelo o agregar features de interaccion temporal (ej. edad x spread, dias_restantes x volumen).

# %% [markdown]
# ---
# ## 7. Category Intelligence
#
# ¿Qué categorías dominan el mercado? ¿Cuáles son más predecibles?
# ¿Hay categorías con mejores oportunidades (más ineficientes)?

# %%
from src.features.categorical import CategoryEncoder

cat_enc = CategoryEncoder()

# Asignar categorías
df_act['category'] = [cat_enc.id_to_cat[cat_enc.encode(m)] for m in active_parsed]
df_res['category'] = [cat_enc.id_to_cat[cat_enc.encode(m)] for m in resolved_parsed[:len(df_res)]]

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Distribución de mercados por categoría
ax = axes[0, 0]
cat_counts = df_act['category'].value_counts()
cat_counts = cat_counts[cat_counts > 0]
cat_counts.plot.barh(ax=ax, color=PALETTE[0], alpha=0.8)
ax.set_title('Mercados Activos por Categoría')
ax.set_xlabel('Cantidad')

# 2. Volumen total por categoría
ax = axes[0, 1]
vol_by_cat = df_act.groupby('category')['volume24hr'].sum().sort_values()
vol_by_cat = vol_by_cat[vol_by_cat > 0]
vol_by_cat.plot.barh(ax=ax, color=PALETTE[1], alpha=0.8)
ax.set_title('Volumen 24h Total por Categoría')
ax.set_xlabel('Volumen ($)')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, p: f'${x:,.0f}'))

# 3. Spread mediano por categoría (ineficiencia por sector)
ax = axes[1, 0]
spread_by_cat = df_act.groupby('category')['spread'].median().sort_values(ascending=False)
spread_by_cat = spread_by_cat.dropna()
if len(spread_by_cat) > 0:
    colors = plt.cm.RdYlGn_r(np.linspace(0.2, 0.8, len(spread_by_cat)))
    spread_by_cat.plot.barh(ax=ax, color=colors, alpha=0.8)
ax.set_title('Spread Mediano por Categoría\n(mayor spread = más ineficiente)')
ax.set_xlabel('Spread mediano')

# 4. Tasa de resolución "Yes" por categoría (sesgo de resolución)
ax = axes[1, 1]
if 'resolution' in df_res.columns:
    df_res['resolved_yes'] = df_res['resolution'].str.strip().str.lower() == 'yes'
    yes_rate = df_res.groupby('category').agg(
        yes_rate=('resolved_yes', 'mean'),
        n=('resolved_yes', 'count'),
    )
    yes_rate = yes_rate[yes_rate['n'] >= 5].sort_values('yes_rate')
    bars = ax.barh(yes_rate.index, yes_rate['yes_rate'], color=PALETTE[2], alpha=0.8)
    ax.axvline(0.5, color='gray', ls='--', alpha=0.5)
    ax.set_title('Tasa de Resolución "Yes" por Categoría\n(sesgo de resolución)')
    ax.set_xlabel('% que resolvió "Yes"')
    for bar, (_, row) in zip(bars, yes_rate.iterrows()):
        ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height()/2,
                f'n={int(row["n"])}', va='center', fontsize=8, color='gray')

plt.suptitle('Análisis por Categoría', fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(fig_dir / '01_category_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways del Analisis por Categoria
#
# **Distribucion de Mercados:**
# - **"unknown"** domina con ~480 mercados — el clasificador de categorias no logra etiquetar la mayoria. Esto sugiere que mejorar la clasificacion de categorias podria ser un quick win para el modelo.
# - **crypto** y **politics** son las categorias mejor representadas (~180 cada una), seguidas de **sports** (~100).
# - **economics**, **finance** y **technology** tienen muy pocos mercados — muestras pequenas para esas categorias.
#
# **Volumen por Categoria:**
# - **"unknown"** lidera en volumen total ($40M+) — probablemente porque agrupa muchos mercados diversos de alto interes.
# - **politics** y **crypto** son las categorias con mas volumen real (~$15-20M) — son los mercados "core" de Polymarket.
# - **elections** y **entertainment** tienen volumen casi nulo a pesar de tener mercados — baja liquidez, potencialmente mas ineficientes.
#
# **Spread por Categoria (Ineficiencia):**
# - **politics** tiene el spread mas alto (~0.002) — sorprendente dado su alto volumen. Posiblemente por la naturaleza polarizada de estos mercados.
# - **economics** y **elections** tambien con spreads altos — mercados con incertidumbre genuina.
# - **entertainment** tiene el spread mas bajo — mercados faciles/predecibles.
#
# **Tasa de Resolucion "Yes" (Sesgo):**
# - **crypto** tiene la tasa mas alta (~63%) — sesgo alcista en mercados cripto (la gente tiende a apostar que los precios suben).
# - **finance** (~50%) es la mas balanceada.
# - **economics** (~5%) tiene la tasa mas baja con n=11 — muestra muy pequena, no confiable.
# - **sports** y **technology** rondan el 25-30% — mercados donde "No" domina.
#
# **Implicaciones para el modelo:**
# - La **categoria es un feature informativo**: cada una tiene spread, volumen y sesgo de resolucion distintos.
# - **politics + economics** combinan spreads altos con volumen — mercados donde el modelo tiene mas chance de encontrar alpha.
# - El sesgo de resolucion por categoria (ej. crypto=63% Yes, sports=25% Yes) es informacion que el modelo deberia aprender como prior.
# - Priorizar mejorar la clasificacion de la categoria "unknown" — casi la mitad de los datos esta sin categorizar.

# %% [markdown]
# ---
# ## 8. Outlier & Anomaly Detection
#
# Identificar mercados atípicos que podrían sesgar el modelo o representar
# oportunidades interesantes.

# %%
# ── Z-score anomaly detection en features numéricas ──
anomaly_cols = ['price_yes', 'volume24hr', 'liquidity', 'spread', 'volume_liquidity_ratio']
anomaly_cols = [c for c in anomaly_cols if c in df_act.columns]

z_scores = df_act[anomaly_cols].apply(lambda x: np.abs(stats.zscore(x, nan_policy='omit')))
z_scores.columns = [f'z_{c}' for c in anomaly_cols]

# Un mercado es "anómalo" si tiene z > 3 en al menos 2 features
df_act_z = pd.concat([df_act, z_scores], axis=1)
high_z_count = (z_scores > 3).sum(axis=1)
anomalous = df_act_z[high_z_count >= 2]

print(f'Mercados con z > 3 en 2+ features: {len(anomalous)} / {len(df_act)}')
if len(anomalous) > 0:
    display_cols = ['question', 'price_yes', 'volume24hr', 'liquidity', 'spread']
    display_cols = [c for c in display_cols if c in anomalous.columns]
    print('\nTop anomalías:')
    print(anomalous.nlargest(10, 'volume24hr')[display_cols].to_string())

# %%
# ── "Mercados dormidos": alto volumen total pero bajo volumen 24h ──
# Estos mercados tuvieron actividad pasada pero ahora están inactivos
# Podrían representar mercados con información asimétrica

active_with_vol = df_act[(df_act['volume'] > 0) & (df_act['volume24hr'] >= 0)].copy()
if len(active_with_vol) > 0:
    active_with_vol['activity_ratio'] = (
        active_with_vol['volume24hr'] / active_with_vol['volume']
    ).replace([np.inf, -np.inf], np.nan)

    fig, ax = plt.subplots(figsize=(12, 6))
    ratio = active_with_vol['activity_ratio'].dropna()
    ratio = ratio[ratio <= ratio.quantile(0.95)]

    sns.histplot(ratio, bins=50, ax=ax, color=PALETTE[3], alpha=0.7, kde=True)
    ax.axvline(ratio.median(), color='red', ls='--',
               label=f'Mediana: {ratio.median():.4f}')
    ax.set_title('Activity Ratio (Vol24h / Vol Total)\n'
                 'Valores bajos = mercados "dormidos" con potencial de información asimétrica')
    ax.set_xlabel('Activity Ratio')
    ax.legend()
    plt.tight_layout()
    plt.show()

    # Top dormidos
    dormant = active_with_vol.nsmallest(10, 'activity_ratio')
    show_cols = ['question', 'price_yes', 'volume', 'volume24hr', 'activity_ratio']
    show_cols = [c for c in show_cols if c in dormant.columns]
    print('Top 10 mercados dormidos (mayor volumen histórico, menor actividad reciente):')
    print(dormant[show_cols].to_string())

# %% [markdown]
# ### Takeaways de Outlier & Anomaly Detection
#
# **Z-Score Anomalies (9 de 1000 mercados):**
# - Dos tipos claros de anomalias:
#   - **Mercados de alta liquidez con spread bajo** (Fed, Judy Shelton): alto volumen institucional, mercados eficientes — poco alpha.
#   - **Mercados de baja liquidez con spread altisimo** (Hibachi token: spread=0.50, esports: spread=0.85-0.89): mercados casi iliquidos donde el precio es poco confiable. El spread de 0.85 en esports/cricket significa que comprar y vender inmediatamente pierde ~85% — son mercados con poquísima actividad real.
# - **Implicacion**: el modelo deberia filtrar mercados con spread > 0.3 o liquidez < $100 — no son operables.
#
# **Activity Ratio (Vol24h / Vol Total):**
# - **Mediana de 0.09** — la mayoria de mercados opera menos del 10% de su volumen historico en un dia.
# - Distribucion fuertemente sesgada a la izquierda: muchos mercados "dormidos" con activity ratio < 0.05.
# - Cola derecha (ratio > 0.6): mercados nuevos donde la mayoria de su volumen es reciente.
#
# **Mercados Dormidos (top 10):**
# - Todos son mercados de **nominaciones presidenciales 2028** y **NBA Finals 2026** — eventos lejanos con volumen historico de $25-38M pero actividad diaria minima ($12K-40K).
# - Activity ratios de 0.0003-0.001 — basicamente sin operacion reciente.
# - Estos mercados tienen precios muy bajos (0.005-0.01) y volumen historico enorme. La hipotesis de "informacion asimetrica" probablemente no aplica aqui — simplemente son longshots de muy largo plazo donde ya no hay interes activo.
#
# **Implicaciones para el modelo:**
# - Usar activity_ratio como feature: valores muy bajos indican mercados estancados (precios desactualizados = potencialmente mal calibrados).
# - Filtrar mercados con liquidez extremadamente baja o spread > 0.3 del pipeline de scoring — no son operables en la practica.
# - Los mercados de largo plazo (2028) tienen dinamicas fundamentalmente distintas — considerar excluirlos o tratarlos como una clase aparte.

# %% [markdown]
# ---
# ## 9. Label Viability
#
# Antes de construir features, ¿es viable el label que queremos predecir?
# ¿Qué tan desbalanceado está? ¿Hay suficiente señal?

# %%
# ── Simular labeling con diferentes thresholds ──
# Ahora usamos snapshot prices reales del historial de precios

thresholds = [0.01, 0.03, 0.05, 0.10, 0.15, 0.20]
label_stats = []

for thresh in thresholds:
    labels = []
    for m in resolved_parsed:
        snapshot_price = get_snapshot_price(m, price_histories=price_histories, snapshot_offset_days=SNAPSHOT_OFFSET_DAYS)
        if snapshot_price is None:
            continue
        label = compute_label(m, snapshot_price, profit_threshold=thresh)
        if label >= 0:
            labels.append(label)

    n_total = len(labels)
    n_pos = sum(labels)
    label_stats.append({
        'threshold': thresh,
        'total': n_total,
        'positives': n_pos,
        'negatives': n_total - n_pos,
        'pos_rate': n_pos / n_total if n_total > 0 else 0,
    })

ls_df = pd.DataFrame(label_stats)
print('Sensibilidad del label al profit_threshold:')
print(ls_df.to_string(index=False))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Tasa de positivos por threshold
ax = axes[0]
ax.bar([str(t) for t in ls_df['threshold']], ls_df['pos_rate'],
       color=PALETTE[0], alpha=0.8)
ax.axhline(0.5, color='gray', ls='--', alpha=0.5, label='Balance 50/50')
ax.set_xlabel('Profit Threshold')
ax.set_ylabel('Tasa de Positivos (Buy)')
ax.set_title('Balance de Clases por Threshold')
ax.legend()

# Stacked bar
ax = axes[1]
ax.bar([str(t) for t in ls_df['threshold']], ls_df['positives'],
       label='Buy', color=PALETTE[2], alpha=0.8)
ax.bar([str(t) for t in ls_df['threshold']], ls_df['negatives'],
       bottom=ls_df['positives'], label='No Buy', color=PALETTE[1], alpha=0.8)
ax.set_xlabel('Profit Threshold')
ax.set_ylabel('Cantidad')
ax.set_title('Distribucion de Labels por Threshold')
ax.legend()

plt.suptitle('Viabilidad del Label de Entrenamiento', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_label_viability.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── Distribucion de retornos potenciales (label continua) ──
from src.data.preprocessing import compute_continuous_label

returns = []
for m in resolved_parsed:
    snapshot = get_snapshot_price(m, price_histories=price_histories, snapshot_offset_days=SNAPSHOT_OFFSET_DAYS)
    if snapshot is None:
        continue
    ret = compute_continuous_label(m, snapshot)
    if ret is not None:
        returns.append(ret)

returns = np.array(returns)
print(f'Retornos calculados: {len(returns)}')
print(f'  Media:    {returns.mean():.3f}')
print(f'  Mediana:  {np.median(returns):.3f}')
print(f'  Std:      {returns.std():.3f}')
print(f'  % rentable: {(returns > 0).mean():.1%}')

fig, ax = plt.subplots(figsize=(12, 5))
ax.hist(returns, bins=60, color=PALETTE[0], alpha=0.7, edgecolor='white')
ax.axvline(0, color='red', ls='--', lw=1.5, label='Breakeven')
ax.axvline(returns.mean(), color='orange', ls='--', lw=1.2,
           label=f'Media: {returns.mean():.3f}')
ax.set_xlabel('Retorno (payout - precio compra)')
ax.set_ylabel('Frecuencia')
ax.set_title('Distribucion de Retornos Potenciales en Mercados Resueltos\n'
             f'(comprando "Yes" al snapshot price, {SNAPSHOT_OFFSET_DAYS}d antes de resolucion)')
ax.legend()
plt.tight_layout()
plt.savefig(fig_dir / '01_return_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Takeaways de Label Viability
#
# **Resultado critico: el snapshot a 7 dias es demasiado tardio.**
#
# **Balance de Clases:**
# - De 917 mercados con snapshot price, solo **8 son "Buy"** al threshold mas bajo (1%) y **0 a partir del 10%**.
# - El desbalance es ~99% No Buy / 1% Buy — un modelo entrenado asi predecira siempre "No Buy" y tendra 99% accuracy sin aprender nada.
#
# **Distribucion de Retornos:**
# - Media: -0.002, Std: 0.024 — retornos concentrados en ~0 con varianza casi nula.
# - 25.4% rentable, pero las ganancias son minimas (la barra gigante esta justo en 0).
#
# **Diagnostico: el mercado ya "sabe" la respuesta 7 dias antes.**
# - A 7 dias de resolucion, los precios ya convergieron a ~0 o ~1.
# - Comprar "Yes" a precio 0.98 y que resuelva Yes da retorno = (1-0.98)/0.98 = 2% — por debajo del threshold.
# - Comprar "Yes" a precio 0.02 y que resuelva No da retorno = -0.02 — perdida minima.
# - **No hay alpha a 7 dias porque ya no hay incertidumbre.**
#
# **Solucion: mover el snapshot mas atras en el tiempo.**
#
# | Snapshot offset | Hipotesis |
# |---|---|
# | 7 dias (actual) | Mercado ya decidido. Sin alpha. |
# | 30 dias | Algo de incertidumbre. Mejor balance de labels. |
# | 60-90 dias | Incertidumbre real. Labels mas balanceados, pero menos mercados con historial tan largo. |
# | Fecha de creacion | Maxima incertidumbre, pero snapshot muy lejano a resolucion — el mundo cambia mucho. |
#
# **Proximos pasos recomendados:**
# 1. Re-ejecutar el labeling con `SNAPSHOT_OFFSET_DAYS = 30` y `60` para encontrar el sweet spot.
# 2. El offset ideal es aquel donde: (a) hay suficientes labels positivos (~20-40%), (b) los retornos tienen varianza suficiente, (c) hay suficientes mercados con historial.
# 3. Considerar usar **multiples snapshots por mercado** como data augmentation — un mercado a 90, 60 y 30 dias da 3 training examples.

# %% [markdown]
# ---
# ## 10. Key Findings & Hypotheses
#
# Resumen ejecutivo de los hallazgos del EDA.

# %%
# ── Summary dashboard ──
fig = plt.figure(figsize=(18, 14))
gs = fig.add_gridspec(3, 3, hspace=0.4, wspace=0.3)

# 1. Precio distribution
ax1 = fig.add_subplot(gs[0, 0])
prices = df_act['price_yes'].dropna()
sns.histplot(prices, bins=40, kde=True, ax=ax1, color=PALETTE[0], alpha=0.7)
ax1.set_title('Dist. Precio Yes', fontsize=10)
ax1.set_xlabel('')

# 2. Volume log dist
ax2 = fig.add_subplot(gs[0, 1])
vol = df_act['volume24hr'].replace(0, np.nan).dropna()
if len(vol) > 0:
    sns.histplot(np.log10(vol + 1), bins=40, kde=True, ax=ax2, color=PALETTE[1], alpha=0.7)
ax2.set_title('Volumen 24h (log)', fontsize=10)
ax2.set_xlabel('')

# 3. Calibration mini
ax3 = fig.add_subplot(gs[0, 2])
if len(calibration) > 0:
    ax3.plot([0, 1], [0, 1], 'k--', alpha=0.3)
    ax3.scatter(calibration['mean_price'], calibration['actual_yes_rate'],
               c=PALETTE[0], s=60, zorder=5)
    ax3.plot(calibration['mean_price'], calibration['actual_yes_rate'],
            '-', color=PALETTE[0], alpha=0.5)
ax3.set_title(f'Calibracion (Brier={brier:.3f})', fontsize=10)
ax3.set_xlabel('')
ax3.set_aspect('equal')

# 4. Category counts
ax4 = fig.add_subplot(gs[1, 0])
cat_counts.head(8).plot.barh(ax=ax4, color=PALETTE[2], alpha=0.8)
ax4.set_title('Top Categorias', fontsize=10)

# 5. Spread por categoria
ax5 = fig.add_subplot(gs[1, 1])
if len(spread_by_cat) > 0:
    spread_by_cat.head(8).plot.barh(ax=ax5, color=PALETTE[3], alpha=0.8)
ax5.set_title('Spread por Categoria', fontsize=10)

# 6. Returns distribution
ax6 = fig.add_subplot(gs[1, 2])
ax6.hist(returns, bins=40, color=PALETTE[4], alpha=0.7, edgecolor='white')
ax6.axvline(0, color='red', ls='--')
ax6.set_title(f'Retornos (media={returns.mean():.2f})', fontsize=10)
ax6.set_xlabel('')

# 7-9: Key metrics as text
ax7 = fig.add_subplot(gs[2, :])
ax7.axis('off')

n_active = len(df_act)
n_resolved = len(df_res)
median_price = df_act['price_yes'].median()
median_vol = df_act['volume24hr'].median()
median_spread = df_act['spread'].median()
pct_profitable = (returns > 0).mean() * 100 if len(returns) > 0 else 0
separator = '─' * 80

summary_text = (
    f'RESUMEN DEL EDA\n'
    f'{separator}\n\n'
    f'  Mercados activos: {n_active:,}    |    Mercados resueltos: {n_resolved:,}\n'
    f'  Precio Yes mediano: {median_price:.2f}    |    Spread mediano: {median_spread:.4f}\n'
    f'  Volumen 24h mediano: ${median_vol:,.0f}    |    Brier Score: {brier:.4f}\n'
    f'  % trades rentables (baseline): {pct_profitable:.1f}%\n\n'
    f'HIPOTESIS PARA EL MODELO\n'
    f'{separator}\n\n'
    f'  H1: Mercados con spread alto y volumen bajo son menos eficientes\n'
    f'  H2: Mercados cercanos a resolucion tienen precios mas precisos\n'
    f'  H3: Ciertas categorias (low-volume) tienen mas alpha\n'
    f'  H4: El mercado sobrevalora longshots (bias inverso al esperado)\n'
    f'  H5: Snapshot a 7d es demasiado tardio — explorar 30-90d\n'
)
ax7.text(0.05, 0.95, summary_text, transform=ax7.transAxes,
         fontsize=11, verticalalignment='top', fontfamily='monospace',
         bbox=dict(boxstyle='round', facecolor='#f0f0f0', alpha=0.8))

plt.suptitle('Polymarket EDA — Summary Dashboard',
             fontsize=16, fontweight='bold', y=1.01)
plt.savefig(fig_dir / '01_summary_dashboard.png', dpi=150, bbox_inches='tight')
plt.show()

print('EDA completo. Figuras guardadas en figures/.')
# Out:
# EDA completo. Figuras guardadas en figures/.

# %% [markdown]
# ---
# ## Resumen Final de Hallazgos del EDA
#
# ### Panorama General
#
# Polymarket es un mercado de prediccion con **~1,000 mercados activos** y **~3,000 resueltos** en nuestro dataset.
# Los precios representan probabilidades implicitas (0 a 1) y el mercado opera con spreads generalmente bajos,
# lo que indica **eficiencia razonable pero no perfecta**.
#
# ### Hallazgos Clave por Seccion
#
# | # | Seccion | Hallazgo Principal | Relevancia para ML |
# |---|---------|-------------------|--------------------|
# | 1 | **Data Quality** | Datos completos para features core (precio, volumen, liquidez). Campos JSON-string parseados correctamente. | Pipeline de preprocessing robusto. |
# | 2 | **Univariate** | Mercado dominado por longshots (mediana precio ~0.02). Volumen y liquidez log-normales. Spreads concentrados pero con outliers. | El modelo vera mayormente eventos improbables. Necesita distinguir longshots con/sin valor. |
# | 3 | **Bivariate** | Alta redundancia volume-liquidity (r=0.71). `volume24hr` es independiente y valioso. Spread correlaciona con vol/liq ratio (r=0.69). | Reducir features redundantes. Conservar `volume24hr` y `spread` como features clave. |
# | 4 | **Calibracion** | Mercado **sobreestima** probabilidades en rango bajo-medio. Brier Score aceptable pero con espacio para mejora. | Alpha existe en rango 0.20-0.80, no en longshots. El modelo debe ajustar hacia abajo. |
# | 5 | **Favorite-Longshot** | Bias **inverso** al esperado: longshots sobrevalorados, no infravalorados. Solo favoritos fuertes (>0.90) estan bien calibrados. | Comprar longshots es perdedor en promedio. Oportunidad en mid-range mal calibrado. |
# | 6 | **Temporal** | Mediana ciclo de vida: 169 dias. Spreads mas altos en mercados de mediano plazo (100-370 dias). Crecimiento explosivo reciente. | Mercados de mediano plazo = zona de oportunidad. Features temporales son informativos. |
# | 7 | **Categorias** | `unknown` domina (48%). Politics + crypto = core. Sesgo Yes en crypto (63%), No en sports (25%). Spread alto en politics. | Categoria como feature con prior de resolucion. Mejorar clasificador de unknown. |
# | 8 | **Outliers** | 9 anomalias (spread >0.3 = inoperable). Activity ratio mediana 0.09. Mercados dormidos = largo plazo sin actividad. | Filtrar spread >0.3. Usar activity_ratio como feature. Excluir mercados inoperables. |
# | 9 | **Label Viability** | **Snapshot a 7 dias es inutil** — 99% No Buy. Media retorno ~0, std ~0.024. Mercado ya decidido a 7d. | Hallazgo critico: mover snapshot a 30-90 dias. Re-evaluar todo el labeling. |
#
# ### Hallazgo Mas Importante
#
# > **El snapshot temporal es la variable mas critica del proyecto.** A 7 dias de la resolucion,
# > los precios ya convergieron a su valor final (~0 o ~1), eliminando toda incertidumbre y por lo
# > tanto todo alpha potencial. El modelo solo puede funcionar si evaluamos mercados **semanas o meses**
# > antes de que resuelvan, cuando los precios aun contienen incertidumbre genuina.
#
# ### Perfil del Mercado Ideal para el Modelo
#
# Basado en todos los findings, el mercado con mayor probabilidad de alpha tiene:
# - **Precio**: rango 0.20-0.80 (incertidumbre real, no longshot ni favorito claro)
# - **Spread**: >0.001 pero <0.30 (ineficiente pero operable)
# - **Dias a resolucion**: 30-150 dias (suficiente incertidumbre, no tan lejano)
# - **Volumen 24h**: >$1,000 (precio contiene informacion real)
# - **Categoria**: politics, economics (spreads altos + volumen)
# - **Activity ratio**: >0.01 (mercado activo, precio actualizado)
#
# ### Proximos Pasos (EDA Fine-Tuned)
#
# 1. **Multi-offset snapshot analysis**: Evaluar 7d, 30d, 60d, 90d para encontrar el sweet spot del labeling
# 2. **Analisis de series de tiempo**: Estudiar trayectorias de precio, velocidad de convergencia, volatilidad
# 3. **Hipotesis refinadas**: Formular hipotesis especificas y testables para el modelo ML

# %% [markdown]
# ---
# ## 11. Fine-Tuned EDA: Snapshot Offset & Time Series Analysis
#
# El EDA inicial revelo que el snapshot a 7 dias es inutil para generar labels.
# Aqui exploramos multiples offsets y analizamos las series de tiempo de precios
# para entender **como y cuando** convergen los mercados.

# %%
# ── 11a. Multi-Offset Snapshot Analysis ──
# Evaluamos labels con offsets de 7, 30, 60, 90 y 120 dias

offsets = [7, 14, 30, 60, 90, 120]
profit_thresh = 0.05  # 5% de retorno minimo

offset_results = []

for offset in offsets:
    labels = []
    prices_collected = []
    for m in resolved_parsed:
        sp = extract_snapshot_from_history(m, price_histories, offset_days=offset)
        if np.isnan(sp) or sp <= 0.02 or sp >= 0.98:
            continue
        label = compute_label(m, sp, profit_threshold=profit_thresh)
        if label >= 0:
            labels.append(label)
            prices_collected.append(sp)
    
    n_total = len(labels)
    n_pos = sum(labels)
    prices_arr = np.array(prices_collected)
    offset_results.append({
        'offset_days': offset,
        'n_markets': n_total,
        'n_buy': n_pos,
        'n_no_buy': n_total - n_pos,
        'buy_rate': n_pos / n_total if n_total > 0 else 0,
        'mean_snapshot_price': prices_arr.mean() if len(prices_arr) > 0 else 0,
        'std_snapshot_price': prices_arr.std() if len(prices_arr) > 0 else 0,
        'price_in_mid_range': ((prices_arr > 0.10) & (prices_arr < 0.90)).mean() if len(prices_arr) > 0 else 0,
    })

offset_df = pd.DataFrame(offset_results)
print('Analisis de sensibilidad al snapshot offset (profit_threshold=5%):')
print(offset_df.to_string(index=False))

# ── Visualizacion ──
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Buy rate por offset
ax = axes[0, 0]
colors = ['#FF5722' if r < 0.10 else '#FF9800' if r < 0.20 else '#4CAF50'
          for r in offset_df['buy_rate']]
ax.bar([str(o) + 'd' for o in offset_df['offset_days']], offset_df['buy_rate'],
       color=colors, alpha=0.8, edgecolor='gray')
ax.axhline(0.20, color='green', ls='--', alpha=0.5, label='20% (target minimo)')
ax.axhline(0.50, color='gray', ls='--', alpha=0.3, label='50% (balance perfecto)')
ax.set_xlabel('Snapshot Offset (dias antes de resolucion)')
ax.set_ylabel('Buy Rate')
ax.set_title('Tasa de "Buy" por Offset\n(verde = zona viable para ML)')
ax.legend(fontsize=9)
ax.set_ylim(0, min(1.0, offset_df['buy_rate'].max() * 1.3 + 0.1))

# 2. N mercados disponibles por offset
ax = axes[0, 1]
ax.bar([str(o) + 'd' for o in offset_df['offset_days']], offset_df['n_markets'],
       color=PALETTE[0], alpha=0.8)
ax.set_xlabel('Snapshot Offset')
ax.set_ylabel('N mercados con snapshot valido')
ax.set_title('Mercados Disponibles por Offset\n(mas offset = menos mercados con historial)')

# 3. Distribucion de snapshot prices por offset
ax = axes[1, 0]
for i, offset in enumerate(offsets):
    sp_list = []
    for m in resolved_parsed:
        sp = extract_snapshot_from_history(m, price_histories, offset_days=offset)
        if not np.isnan(sp) and 0.02 < sp < 0.98:
            sp_list.append(sp)
    if sp_list:
        ax.hist(sp_list, bins=30, alpha=0.4, label=str(offset) + 'd',
                color=PALETTE[i % len(PALETTE)])
ax.set_xlabel('Snapshot Price')
ax.set_ylabel('Frecuencia')
ax.set_title('Distribucion de Snapshot Prices por Offset')
ax.legend(fontsize=8)

# 4. % de precios en rango medio (0.10-0.90)
ax = axes[1, 1]
ax.plot([str(o) + 'd' for o in offset_df['offset_days']],
        offset_df['price_in_mid_range'] * 100, 'o-', color=PALETTE[2],
        markersize=8, linewidth=2)
ax.fill_between(range(len(offsets)), offset_df['price_in_mid_range'] * 100,
                alpha=0.2, color=PALETTE[2])
ax.set_xlabel('Snapshot Offset')
ax.set_ylabel('% precios en rango 0.10-0.90')
ax.set_title('Proporcion de Precios con Incertidumbre Real\n(mayor % = mas informativo)')

plt.suptitle('Sensibilidad al Snapshot Offset', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_snapshot_offset_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

# Recomendacion automatica
viable = offset_df[(offset_df['buy_rate'] >= 0.15) & (offset_df['n_markets'] >= 100)]
if len(viable) > 0:
    best = viable.iloc[0]
    print(f'\nOFFSET RECOMENDADO: {int(best["offset_days"])} dias')
    print(f'  Buy rate: {best["buy_rate"]:.1%}')
    print(f'  N mercados: {int(best["n_markets"])}')
    print(f'  % en mid-range: {best["price_in_mid_range"]:.1%}')
else:
    print('\nNingun offset alcanza buy_rate >= 15% con N >= 100.')
    print('Considerar: (a) mas datos historicos, (b) threshold mas bajo, (c) label continua.')
    # Mostrar el mejor disponible
    best_idx = offset_df['buy_rate'].idxmax()
    best = offset_df.iloc[best_idx]
    print(f'Mejor disponible: {int(best["offset_days"])}d con buy_rate={best["buy_rate"]:.1%}, N={int(best["n_markets"])}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10 labels = []
#      11 prices_collected = []
# ---> 12 for m in resolved_parsed:
#      13     sp = extract_snapshot_from_history(m, price_histories, offset_days=offset)
#      14     if np.isnan(sp) or sp <= 0.02 or sp >= 0.98:
#
# NameError: name 'resolved_parsed' is not defined

# %%
# ── 11b. Distribucion de Retornos Continuos por Offset ──
# En lugar de label binaria, analizar la distribucion de retornos
# Esto determina si hay suficiente varianza para un modelo de regresion

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

return_stats = []

for i, offset in enumerate(offsets):
    rets = []
    for m in resolved_parsed:
        sp = extract_snapshot_from_history(m, price_histories, offset_days=offset)
        if np.isnan(sp) or sp <= 0.02 or sp >= 0.98:
            continue
        ret = compute_continuous_label(m, sp)
        if ret is not None:
            rets.append(ret)
    
    rets = np.array(rets)
    ax = axes[i]
    
    if len(rets) > 0:
        ax.hist(rets, bins=50, color=PALETTE[i % len(PALETTE)], alpha=0.7, edgecolor='white')
        ax.axvline(0, color='red', ls='--', lw=1.5)
        ax.axvline(rets.mean(), color='orange', ls='--', lw=1,
                   label=f'Media: {rets.mean():.3f}')
        ax.set_title(f'Offset = {offset}d (N={len(rets)})\n'
                     f'Std={rets.std():.3f}, Rentable={(rets>0).mean():.0%}',
                     fontsize=10)
        ax.legend(fontsize=8)
        
        return_stats.append({
            'offset': offset,
            'n': len(rets),
            'mean_return': rets.mean(),
            'std_return': rets.std(),
            'pct_profitable': (rets > 0).mean(),
            'sharpe_like': rets.mean() / rets.std() if rets.std() > 0 else 0,
            'p25': np.percentile(rets, 25),
            'p75': np.percentile(rets, 75),
        })
    else:
        ax.text(0.5, 0.5, 'Sin datos', ha='center', va='center',
                transform=ax.transAxes, fontsize=12, color='gray')
        ax.set_title(f'Offset = {offset}d', fontsize=10)
    
    ax.set_xlabel('Retorno')

plt.suptitle('Distribucion de Retornos por Snapshot Offset\n'
             '(mas ancha = mas informacion para el modelo)',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_returns_by_offset.png', dpi=150, bbox_inches='tight')
plt.show()

ret_df = pd.DataFrame(return_stats)
print('\nEstadisticas de retornos por offset:')
print(ret_df.to_string(index=False))
print('\nEl offset ideal maximiza: std (varianza de senal), N (datos), y % rentable cercano a 30-50%.')

# %% [markdown]
# ### Takeaways del Analisis Multi-Offset
#
# **Resultado clave: 60 dias es el offset optimo.**
#
# | Offset | N mercados | Buy rate | Media retorno | Std retorno | % rentable | Sharpe-like |
# |--------|-----------|----------|---------------|-------------|------------|-------------|
# | 7d     | 12        | 8.3%     | -0.108        | 0.176       | 41.7%      | -0.61       |
# | 14d    | 44        | 2.3%     | -0.226        | 0.168       | 11.4%      | -1.34       |
# | 30d    | 14        | 7.1%     | -0.274        | 0.331       | 35.7%      | -0.83       |
# | **60d**| **108**   | **65.7%**| **+0.337**    | **0.357**   | **72.2%**  | **+0.94**   |
# | 90d    | 75        | 6.7%     | -0.146        | 0.284       | 13.3%      | -0.51       |
# | 120d   | 19        | 10.5%   | -0.025        | 0.326       | 31.6%      | -0.08       |
#
# **Analisis de los resultados:**
#
# 1. **60 dias es claramente el ganador** — es el unico offset con:
#    - Buy rate >20% (**65.7%**, incluso por encima del balance perfecto)
#    - Retorno medio **positivo** (+0.337)
#    - Sharpe-like ratio positivo (**+0.94**)
#    - Mayor N de mercados (**108**) con 74.1% de precios en mid-range
#
# 2. **Todos los demas offsets tienen retorno medio negativo** — comprar "Yes" al precio de mercado es perdedor a 7d, 14d, 30d, 90d y 120d.
#
# 3. **El patron no es monotono**: no es que "mas offset = mejor". 60d tiene un pico drastico, y 90d vuelve a caer. Esto sugiere que a **60 dias** los mercados tienen precios con suficiente incertidumbre real, pero a 90d+ ya hay demasiada incertidumbre (ruido supera senal).
#
# 4. **Distribucion de precios a 60d**: la mayoria de snapshots estan en el rango 0.20-0.60 — zona donde la calibracion del mercado tiene errores sistematicos (como vimos en la Seccion 5).
#
# **Implicaciones directas:**
# - Usar `SNAPSHOT_OFFSET_DAYS = 60` para el labeling del modelo
# - Con 108 mercados a 60d, el dataset es pequeno. Opciones:
#   - **Multi-snapshot augmentation**: usar 30d, 60d, 90d como ejemplos separados del mismo mercado
#   - **Descargar mas mercados historicos** (aumentar `max_markets` de 2000 a 5000+)
#   - **Label continua** (regresion del retorno) en lugar de binaria para aprovechar toda la informacion
# - El Sharpe-like de 0.94 a 60d indica que **hay senal real** — no es solo ruido
#
# **Precaucion sobre el buy rate de 65.7%:**
# - Un buy rate tan alto (>50%) podria indicar un sesgo en el sampling: los mercados con historial a 60d podrian ser un subconjunto no representativo.
# - Hay que validar si este patron se mantiene con mas datos.

# %% [markdown]
# ---
# ### 11c. Analisis de Series de Tiempo de Precios
#
# Estudiamos las **trayectorias de precio** completas de los mercados:
# - Como convergen los precios hacia 0 o 1?
# - Hay patrones de volatilidad que predigan la resolucion?
# - A que velocidad se incorpora la informacion?

# %%
# ── Analisis de trayectorias de precio ──
# Normalizamos el eje temporal: 0% = creacion, 100% = resolucion

trajectories_yes = []  # Mercados que resolvieron Yes
trajectories_no = []   # Mercados que resolvieron No

for m in resolved_parsed:
    market_id = str(m.get('id', ''))
    history = price_histories.get(market_id, [])
    if len(history) < 10:  # Necesitamos suficientes puntos
        continue
    
    # Determinar resolucion
    outcome_prices = m.get('outcomePrices', [])
    if isinstance(outcome_prices, str):
        try:
            outcome_prices = json.loads(outcome_prices)
        except Exception:
            continue
    if not outcome_prices or len(outcome_prices) < 2:
        continue
    try:
        p0 = float(outcome_prices[0])
    except (ValueError, TypeError):
        continue
    
    resolution = 'yes' if p0 >= 0.95 else ('no' if p0 <= 0.05 else 'ambiguous')
    if resolution == 'ambiguous':
        continue
    
    # Obtener timestamps de inicio y fin
    try:
        start_ts = pd.to_datetime(m.get('createdAt', ''), utc=True).timestamp()
        end_ts = pd.to_datetime(m.get('endDate', ''), utc=True).timestamp()
    except Exception:
        continue
    
    if end_ts <= start_ts:
        continue
    
    duration = end_ts - start_ts
    
    # Normalizar tiempo a 0-1
    normalized = []
    for point in history:
        t = point.get('t', 0)
        p = point.get('p', 0)
        if t >= start_ts and t <= end_ts:
            t_norm = (t - start_ts) / duration  # 0 = inicio, 1 = fin
            normalized.append((t_norm, float(p)))
    
    if len(normalized) >= 5:
        if resolution == 'yes':
            trajectories_yes.append(normalized)
        else:
            trajectories_no.append(normalized)

print(f'Trayectorias Yes: {len(trajectories_yes)}')
print(f'Trayectorias No:  {len(trajectories_no)}')

# ── Visualizar trayectorias individuales + promedio ──
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# 1. Trayectorias Yes (muestra)
ax = axes[0]
for traj in trajectories_yes[:50]:  # Max 50 para legibilidad
    ts, ps = zip(*traj)
    ax.plot(ts, ps, alpha=0.15, color=PALETTE[2], linewidth=0.8)
ax.set_xlabel('Tiempo normalizado (0=creacion, 1=resolucion)')
ax.set_ylabel('Precio Yes')
ax.set_title(f'Trayectorias "Yes" (N={len(trajectories_yes)})')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axhline(0.5, color='gray', ls=':', alpha=0.3)

# 2. Trayectorias No (muestra)
ax = axes[1]
for traj in trajectories_no[:50]:
    ts, ps = zip(*traj)
    ax.plot(ts, ps, alpha=0.15, color=PALETTE[1], linewidth=0.8)
ax.set_xlabel('Tiempo normalizado (0=creacion, 1=resolucion)')
ax.set_ylabel('Precio Yes')
ax.set_title(f'Trayectorias "No" (N={len(trajectories_no)})')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axhline(0.5, color='gray', ls=':', alpha=0.3)

# 3. Trayectorias promedio
ax = axes[2]
n_bins_t = 20
t_bins = np.linspace(0, 1, n_bins_t + 1)
t_centers = (t_bins[:-1] + t_bins[1:]) / 2

for label, trajs, color in [('Yes', trajectories_yes, PALETTE[2]),
                              ('No', trajectories_no, PALETTE[1])]:
    avg_prices = []
    std_prices = []
    for i in range(n_bins_t):
        bin_prices = []
        for traj in trajs:
            for t, p in traj:
                if t_bins[i] <= t < t_bins[i + 1]:
                    bin_prices.append(p)
        if bin_prices:
            avg_prices.append(np.mean(bin_prices))
            std_prices.append(np.std(bin_prices))
        else:
            avg_prices.append(np.nan)
            std_prices.append(np.nan)
    
    avg = np.array(avg_prices)
    std = np.array(std_prices)
    valid = ~np.isnan(avg)
    
    ax.plot(t_centers[valid], avg[valid], '-o', color=color,
            label=f'Promedio {label}', markersize=4, linewidth=2)
    ax.fill_between(t_centers[valid], (avg - std)[valid], (avg + std)[valid],
                    alpha=0.15, color=color)

ax.set_xlabel('Tiempo normalizado')
ax.set_ylabel('Precio Yes promedio')
ax.set_title('Trayectoria Promedio: Yes vs No\n(banda = +-1 std)')
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axhline(0.5, color='gray', ls=':', alpha=0.3)

plt.suptitle('Trayectorias de Precio en Mercados Resueltos',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_price_trajectories.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# ── 11d. Velocidad de Convergencia y Volatilidad ──
# Pregunta clave: en que momento del ciclo de vida se "decide" el mercado?

# Calcular metricas de convergencia por ventana temporal
windows = [0.25, 0.50, 0.75, 0.90]  # 25%, 50%, 75%, 90% del ciclo de vida

convergence_data = []

all_trajs = [(traj, 'yes') for traj in trajectories_yes] + \
            [(traj, 'no') for traj in trajectories_no]

for traj, res in all_trajs:
    ts, ps = zip(*traj)
    ts = np.array(ts)
    ps = np.array(ps)
    
    final_price = 1.0 if res == 'yes' else 0.0
    
    for w in windows:
        mask = ts <= w
        if mask.sum() >= 3:
            p_window = ps[mask]
            convergence_data.append({
                'window': w,
                'resolution': res,
                'mean_price': p_window.mean(),
                'volatility': p_window.std(),
                'distance_to_final': abs(p_window[-1] - final_price),
                'price_range': p_window.max() - p_window.min(),
                'last_price': p_window[-1],
            })

conv_df = pd.DataFrame(convergence_data)

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# 1. Distancia al precio final por ventana temporal
ax = axes[0, 0]
for res, color, label in [('yes', PALETTE[2], 'Yes'), ('no', PALETTE[1], 'No')]:
    data = conv_df[conv_df['resolution'] == res]
    grouped = data.groupby('window')['distance_to_final'].median()
    ax.plot(grouped.index * 100, grouped.values, 'o-', color=color,
            label=label, markersize=8, linewidth=2)
ax.set_xlabel('% del ciclo de vida del mercado')
ax.set_ylabel('Distancia mediana al precio final')
ax.set_title('Velocidad de Convergencia\n(menor distancia = mercado mas decidido)')
ax.legend()
ax.set_ylim(0, None)

# 2. Volatilidad por ventana temporal
ax = axes[0, 1]
for res, color, label in [('yes', PALETTE[2], 'Yes'), ('no', PALETTE[1], 'No')]:
    data = conv_df[conv_df['resolution'] == res]
    grouped = data.groupby('window')['volatility'].median()
    ax.plot(grouped.index * 100, grouped.values, 'o-', color=color,
            label=label, markersize=8, linewidth=2)
ax.set_xlabel('% del ciclo de vida')
ax.set_ylabel('Volatilidad mediana (std de precios)')
ax.set_title('Volatilidad por Fase del Mercado\n(alta volatilidad = incertidumbre)')
ax.legend()

# 3. Heatmap: precio promedio en cada (ventana, resolucion)
ax = axes[1, 0]
pivot = conv_df.pivot_table(
    values='mean_price', index='resolution', columns='window', aggfunc='median'
)
pivot.columns = [str(int(c * 100)) + '%' for c in pivot.columns]
sns.heatmap(pivot, annot=True, fmt='.2f', cmap='RdYlGn', center=0.5,
            ax=ax, cbar_kws={'shrink': 0.8})
ax.set_title('Precio Promedio por Fase y Resolucion')
ax.set_xlabel('% del ciclo de vida')

# 4. Separabilidad: diferencia de precios Yes vs No por ventana
ax = axes[1, 1]
sep_data = []
for w in windows:
    yes_prices = conv_df[(conv_df['window'] == w) & (conv_df['resolution'] == 'yes')]['last_price']
    no_prices = conv_df[(conv_df['window'] == w) & (conv_df['resolution'] == 'no')]['last_price']
    if len(yes_prices) > 0 and len(no_prices) > 0:
        sep = yes_prices.mean() - no_prices.mean()
        # Cohen's d como medida de separabilidad
        pooled_std = np.sqrt((yes_prices.std()**2 + no_prices.std()**2) / 2)
        cohens_d = sep / pooled_std if pooled_std > 0 else 0
        sep_data.append({'window': w, 'mean_diff': sep, 'cohens_d': cohens_d})

if sep_data:
    sep_df = pd.DataFrame(sep_data)
    ax.bar([str(int(w*100)) + '%' for w in sep_df['window']],
           sep_df['cohens_d'], color=PALETTE[4], alpha=0.8)
    ax.axhline(0.8, color='green', ls='--', alpha=0.5, label="Cohen's d = 0.8 (grande)")
    ax.axhline(0.5, color='orange', ls='--', alpha=0.5, label="Cohen's d = 0.5 (medio)")
    ax.set_xlabel('% del ciclo de vida')
    ax.set_ylabel("Cohen's d (Yes vs No)")
    ax.set_title('Separabilidad de Precios Yes vs No\n(mayor d = mas facil de predecir)')
    ax.legend(fontsize=8)

plt.suptitle('Convergencia y Separabilidad de Precios',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_convergence_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print('\nSeparabilidad por ventana:')
if sep_data:
    for row in sep_data:
        pct = int(row['window'] * 100)
        print(f"  {pct}% del ciclo: diff={row['mean_diff']:.3f}, Cohen's d={row['cohens_d']:.2f}")

# %%
# ── 11e. Features Extraidos de Series de Tiempo ──
# Evaluar que features de la serie temporal podrian ser utiles para el modelo

ts_features = []

for m in resolved_parsed:
    market_id = str(m.get('id', ''))
    history = price_histories.get(market_id, [])
    if len(history) < 10:
        continue
    
    # Resolucion
    outcome_prices = m.get('outcomePrices', [])
    if isinstance(outcome_prices, str):
        try:
            outcome_prices = json.loads(outcome_prices)
        except Exception:
            continue
    if not outcome_prices or len(outcome_prices) < 2:
        continue
    try:
        p0 = float(outcome_prices[0])
    except (ValueError, TypeError):
        continue
    
    resolution = 'yes' if p0 >= 0.95 else ('no' if p0 <= 0.05 else None)
    if resolution is None:
        continue
    
    prices = np.array([float(pt.get('p', 0)) for pt in history])
    timestamps = np.array([pt.get('t', 0) for pt in history])
    
    if len(prices) < 5:
        continue
    
    # Features de la serie temporal completa
    returns_ts = np.diff(prices)
    
    # Ultimos N puntos (ventana reciente)
    n_recent = min(20, len(prices) // 4)
    recent_prices = prices[-n_recent:] if n_recent > 0 else prices
    recent_returns = np.diff(recent_prices) if len(recent_prices) > 1 else np.array([0])
    
    ts_features.append({
        'market_id': market_id,
        'resolution': resolution,
        'n_points': len(prices),
        # Nivel de precio
        'price_mean': prices.mean(),
        'price_last': prices[-1],
        'price_first': prices[0],
        # Tendencia
        'trend': prices[-1] - prices[0],  # Cambio total
        'trend_recent': recent_prices[-1] - recent_prices[0] if len(recent_prices) > 1 else 0,
        # Volatilidad
        'volatility_full': prices.std(),
        'volatility_recent': recent_prices.std() if len(recent_prices) > 1 else 0,
        # Momentum
        'mean_return': returns_ts.mean() if len(returns_ts) > 0 else 0,
        'recent_mean_return': recent_returns.mean() if len(recent_returns) > 0 else 0,
        # Rango
        'price_range': prices.max() - prices.min(),
        'recent_range': recent_prices.max() - recent_prices.min() if len(recent_prices) > 0 else 0,
        # Asimetria
        'skewness': float(pd.Series(prices).skew()) if len(prices) > 2 else 0,
    })

ts_df = pd.DataFrame(ts_features)
print(f'Mercados con features de serie temporal: {len(ts_df)}')
print(f'  Yes: {(ts_df["resolution"]=="yes").sum()}, No: {(ts_df["resolution"]=="no").sum()}')

# ── Importancia relativa de cada feature para predecir resolucion ──
feature_cols = ['price_mean', 'price_first', 'trend', 'trend_recent',
                'volatility_full', 'volatility_recent', 'mean_return',
                'recent_mean_return', 'price_range', 'recent_range', 'skewness']

ts_df['label'] = (ts_df['resolution'] == 'yes').astype(int)

fig, axes = plt.subplots(3, 4, figsize=(20, 12))
axes = axes.flatten()

separabilities = []
for i, col in enumerate(feature_cols):
    ax = axes[i]
    yes_vals = ts_df[ts_df['label'] == 1][col].dropna()
    no_vals = ts_df[ts_df['label'] == 0][col].dropna()
    
    # Clip outliers para visualizacion
    all_vals = pd.concat([yes_vals, no_vals])
    clip_lo, clip_hi = all_vals.quantile(0.02), all_vals.quantile(0.98)
    
    ax.hist(yes_vals.clip(clip_lo, clip_hi), bins=30, alpha=0.5,
            color=PALETTE[2], label='Yes', density=True)
    ax.hist(no_vals.clip(clip_lo, clip_hi), bins=30, alpha=0.5,
            color=PALETTE[1], label='No', density=True)
    
    # Cohen's d
    pooled_std = np.sqrt((yes_vals.std()**2 + no_vals.std()**2) / 2)
    d = abs(yes_vals.mean() - no_vals.mean()) / pooled_std if pooled_std > 0 else 0
    separabilities.append((col, d))
    
    ax.set_title(f'{col}\n(d={d:.2f})', fontsize=9)
    ax.legend(fontsize=7)

# Hide unused axes
for j in range(len(feature_cols), len(axes)):
    axes[j].axis('off')

plt.suptitle('Distribucion de Features Temporales: Yes vs No\n'
             '(mayor d = mejor separabilidad)',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig(fig_dir / '01_ts_features_separability.png', dpi=150, bbox_inches='tight')
plt.show()

# Ranking de features
separabilities.sort(key=lambda x: -x[1])
print('\nRanking de features temporales por separabilidad (Cohens d):')
for feat, d in separabilities:
    strength = 'FUERTE' if d > 0.8 else 'medio' if d > 0.5 else 'debil'
    print(f'  {feat:25s}  d={d:.3f}  ({strength})')

# %% [markdown]
# ### Takeaways del Analisis de Series de Tiempo
#
# **Trayectorias de Precio (222 Yes, 654 No):**
# - Los mercados que resuelven **"Yes"** mantienen precios altos (promedio ~0.75-0.80) durante todo el ciclo de vida, con una ligera caida en la fase media antes de converger a 1.0.
# - Los mercados que resuelven **"No"** tienen precios consistentemente bajos (~0.05) durante todo el ciclo — la mayoria son longshots que nunca despegaron.
# - La banda de incertidumbre (+-1 std) de los mercados Yes es **mucho mas ancha** que la de los No. Esto significa que los mercados Yes tienen mas variabilidad y son mas dificiles de predecir.
# - Los mercados No muestran un patron interesante: un grupo tiene precios iniciales altos (~0.80+) que caen rapidamente en el primer 20% del ciclo — estos son los "falsos favoritos" que el modelo deberia aprender a detectar.
#
# **Velocidad de Convergencia:**
# - Distancia mediana al precio final es **~0.0005** en todas las ventanas — esto indica que la **mediana** de mercados ya esta decidida desde el inicio (precios extremos).
# - La separabilidad entre Yes y No es **masiva** incluso desde el 25% del ciclo:
#   - 25%: Cohen's d = **12.55** (extremadamente fuerte)
#   - 50%: Cohen's d = **11.31**
#   - 75%: Cohen's d = **49.84**
#   - 90%: Cohen's d = **50.05**
# - Estos Cohen's d tan altos significan que la diferencia de precios entre Yes y No es **enorme** — es un problema "facil" en terminos de separabilidad.
#
# **Volatilidad por Fase:**
# - Mercados **Yes** tienen volatilidad creciente (~0.09 a 0.11) — la incertidumbre aumenta antes de converger.
# - Mercados **No** tienen volatilidad decreciente (~0.05 a 0.03) — rapidamente se consolidan como perdedores.
# - La **divergencia de volatilidad** es una senal potente: si la volatilidad sube, es mas probable que resuelva Yes.
#
# **Ranking de Features Temporales (876 mercados):**
#
# | # | Feature | Cohen's d | Fuerza | Interpretacion |
# |---|---------|-----------|--------|----------------|
# | 1 | `price_mean` | **3.36** | FUERTE | Precio promedio historico: Yes alto, No bajo |
# | 2 | `trend` | **2.71** | FUERTE | Cambio total inicio-a-fin: Yes sube, No cae |
# | 3 | `price_first` | **1.70** | FUERTE | Precio inicial: Yes arranca alto |
# | 4 | `trend_recent` | **1.20** | FUERTE | Momentum reciente: Yes sigue subiendo |
# | 5 | `mean_return` | **1.16** | FUERTE | Retorno promedio por punto: Yes positivo |
# | 6 | `recent_mean_return` | **0.98** | FUERTE | Retorno reciente: señal de momentum |
# | 7 | `price_range` | **0.90** | FUERTE | Amplitud total: Yes oscila mas |
# | 8 | `volatility_full` | **0.84** | FUERTE | Volatilidad total: Yes mas volatil |
# | 9 | `recent_range` | 0.67 | medio | Rango reciente |
# | 10| `volatility_recent` | 0.62 | medio | Volatilidad reciente |
# | 11| `skewness` | 0.19 | debil | Asimetria: poco util |
#
# **Hallazgo clave**: 8 de 11 features temporales tienen separabilidad FUERTE (d > 0.8). Esto confirma que **las series de tiempo contienen mucha informacion predictiva** que los features estaticos solos no capturan.
#
# **Caveat importante:**
# - La separabilidad tan alta (d=3.36 para `price_mean`) sugiere que el problema podria ser "demasiado facil" con estos features — mercados con precio promedio alto casi siempre resuelven Yes.
# - El riesgo es **data leakage temporal**: si `price_mean` incluye informacion de todo el historial (incluyendo periodos cercanos a la resolucion), estamos haciendo trampa.
# - **Solucion**: al construir features para el modelo, calcular `price_mean` solo con datos **anteriores al punto de prediccion**, no de toda la serie.
#
# **Features recomendados para el modelo (en orden de prioridad):**
# 1. `trend_recent` — momentum reciente, bajo riesgo de leakage si se calcula correctamente
# 2. `volatility_full` / `volatility_recent` — patron divergente Yes vs No
# 3. `price_range` — amplitud de movimiento como proxy de incertidumbre del mercado
# 4. `price_first` — precio inicial como prior (no tiene leakage)
# 5. `mean_return` — con ventana temporal controlada

# %% [markdown]
# ---
# ## 12. Hipotesis Refinadas para el Modelo ML
#
# Basado en **todo** el EDA (secciones 1-11) con datos reales de Polymarket:
#
# ### Datos del Proyecto
#
# | Metrica | Valor |
# |---------|-------|
# | Mercados activos | 1,000 |
# | Mercados resueltos | 2,000 |
# | Con price history | 1,739 |
# | Resueltos Yes / No | 222 / 654 (de 876 con series) |
# | Offset optimo | **60 dias** |
# | N mercados a 60d | 108 (buy rate 65.7%) |
# | Retorno medio a 60d | +0.337, Sharpe-like 0.94 |
# | Brier Score mercado (7d) | 0.0018 |
# | Features temporales FUERTES | 8 de 11 (d > 0.8) |
#
# ### Hipotesis de Arquitectura del Modelo
#
# | ID | Hipotesis | Evidencia del EDA | Test |
# |---|-----------|-------------------|------|
# | **H1** | Un modelo de **regresion** (prediciendo retorno continuo) sera mas efectivo que binario. | Label binaria tiene 65.7% Buy a 60d (desbalance inverso). Retornos continuos (std=0.357) capturan mas informacion que una label 0/1. | Comparar RMSE regresion vs F1 clasificacion en validation set. |
# | **H2** | El **offset de 60 dias** es el sweet spot para labeling. | Unico offset con retorno medio positivo (+0.337), Sharpe >0, y N>100. A 90d+ la senal se pierde. | Validar con mas datos (5000+ mercados). Si el patron persiste, es robusto. |
# | **H3** | **Multi-snapshot augmentation** (30d, 60d, 90d) triplicara el training set de ~108 a ~300+. | Cada offset captura una vista diferente del mercado. A 30d N=14, 60d N=108, 90d N=75 = ~197 combinados. | Comparar modelo con single-snapshot (60d) vs multi-snapshot. |
# | **H4** | Features de **series de tiempo** seran los mas predictivos del modelo. | 8 de 11 features tienen Cohen's d > 0.8. `price_mean` d=3.36, `trend` d=2.71. La separabilidad temporal supera ampliamente a los features estaticos. | Ablation study: modelo con vs sin features temporales. |
# | **H5** | La separabilidad tan alta (d > 3) indica posible **data leakage** en algunos features. | `price_mean` incluye toda la serie temporal — informacion post-prediccion. El modelo podria overfit a informacion que no existiria en produccion. | Calcular features solo con ventana anterior al punto de prediccion. Comparar rendimiento. |
#
# ### Hipotesis de Features
#
# | ID | Feature | d de Cohen | Evidencia | Riesgo leakage | Prioridad |
# |---|---------|------------|-----------|----------------|----------|
# | **F1** | `trend_recent` | 1.20 | Momentum reciente con buena separabilidad. Captura si el mercado esta subiendo o bajando. | Bajo (ventana reciente controlable) | **Alta** |
# | **F2** | `volatility_full` | 0.84 | Yes mas volatil (0.09-0.11), No menos volatil (0.05-0.03). Patron divergente claro. | Medio (calcular solo con datos previos) | **Alta** |
# | **F3** | `price_first` | 1.70 | Precio inicial: Yes arranca ~0.40+, No arranca ~0.05. No tiene leakage — es dato del inicio. | **Nulo** | **Alta** |
# | **F4** | `spread` | — | Indicador directo de ineficiencia. Mercados con spread >0.001 y <0.30 son la zona operable. | Nulo | **Alta** |
# | **F5** | `volume24hr` | — | Feature independiente (r<0.2 con otros). Captura atencion reciente del mercado. | Nulo | **Alta** |
# | **F6** | `price_range` | 0.90 | Amplitud total del movimiento. Yes oscila mas. | Medio | Media |
# | **F7** | `category` | — | Prior informativo: crypto 63% Yes, sports 25%. Cada sector tiene sesgo base. | Nulo | Media |
# | **F8** | `activity_ratio` | — | Mediana 0.09. Mercados dormidos tienen precios desactualizados. | Nulo | Media |
# | **F9** | `days_to_resolution` x `spread` | — | Spreads mas altos en mediano plazo (100-370d). Interaccion temporal no-lineal. | Nulo | Media |
# | **F10** | `skewness` | 0.19 | Debil separabilidad. Poco util como feature individual. | Bajo | **Baja** |
#
# ### Hipotesis de Estrategia
#
# | ID | Hipotesis | Evidencia | Implicacion |
# |---|-----------|-----------|-------------|
# | **S1** | El mercado sobrevalora longshots — **no comprar mercados con precio < 0.10**. | Favorite-longshot bias inverso. Retorno negativo en todos los offsets excepto 60d. Longshots casi nunca resuelven Yes. | Pre-filtro: excluir mercados con snapshot_price < 0.10. |
# | **S2** | Filtrar mercados inoperables mejora calidad: **spread < 0.30, liquidez > $100, activity_ratio > 0.001**. | 9 anomalias con spread > 0.30 son inoperables. Mercados dormidos (activity_ratio < 0.001) tienen precios stale. | Pipeline de scoring debe incluir estos filtros antes de evaluar. |
# | **S3** | Mercados con **60 dias a resolucion** ofrecen el mejor balance riesgo-retorno. | Unico offset con Sharpe positivo (0.94). A 7-30d el mercado ya decidio. A 90d+ hay demasiado ruido. | Foco del modelo en ventana 45-75 dias a resolucion. |
# | **S4** | Un modelo de **calibracion** (predecir error del mercado) sera mas robusto que prediccion directa. | El mercado ya tiene informacion (Cohen's d muy alto). El modelo solo necesita corregir sesgos sistematicos (~sobrevaloracion de longshots). | `target = retorno_real - 0` en lugar de `target = resolucion`. |
# | **S5** | **Data augmentation es critica** — 108 mercados no son suficientes para un modelo robusto. | El dataset a 60d es pequeno. Riesgo alto de overfitting con <200 samples. | Priorizar: (1) descargar 5000+ mercados, (2) multi-snapshot, (3) features que generalicen. |
#
#
# ### Conclusiones Finales del EDA
#
# 1. **Hay senal real** en los datos de Polymarket — el Sharpe de 0.94 a 60d y la separabilidad alta de features temporales lo confirman.
# 2. **El principal riesgo es data leakage** — features como `price_mean` (d=3.36) son sospechosamente buenos. Debemos ser rigurosos con las ventanas temporales.
# 3. **El dataset es pequeno** (108 mercados a 60d). Data augmentation y descarga de mas mercados son prioritarios.
# 4. **El mercado de Polymarket es generalmente eficiente** (Brier Score 0.0018 a 7d), pero hay bolsas de ineficiencia en mercados de mediano plazo con spreads altos.
# 5. **El approach mas prometedor**: modelo de regresion con label continua, features temporales con ventanas controladas, y foco en mercados a ~60 dias de resolucion en el rango de precios 0.10-0.90.
