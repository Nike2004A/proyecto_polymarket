# %% [markdown]
# # 02 — Feature Engineering
#
# Este notebook explica y valida la construcción de features antes de correr el pipeline completo.
# No genera los archivos `.npy` finales — eso lo hace `python -m src.features.pipeline`.
#
# **Objetivo**: entender cada feature, ver su distribución y validar que el pipeline funciona correctamente.
#
# Secciones:
# 1. Snapshot anti-leakage — precio 7 días antes de resolución
# 2. Features numéricas — extracción e inspección
# 3. Encoding categórico — categorías por slug
# 4. Labels — distribución con el snapshot price
# 5. Correr el pipeline completo

# %%
import sys
import json
import logging
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

from src.data.preprocessing import (
    build_snapshot_market,
    compute_label,
    _infer_resolution_from_market,
)
from src.features.numerical import extract_numerical_features, NUMERICAL_FEATURE_NAMES, NUM_NUMERICAL_FEATURES
from src.features.categorical import CategoryEncoder, DEFAULT_CATEGORIES

logging.getLogger('src.data.preprocessing').setLevel(logging.ERROR)

plt.rcParams.update({'figure.dpi': 120, 'axes.spines.top': False,
                     'axes.spines.right': False, 'axes.grid': True, 'grid.alpha': 0.3})
PALETTE = ['#4C72B0', '#DD8452', '#55A868', '#C44E52']

RAW = ROOT / 'data' / 'raw'
print(f'Features numéricas: {NUM_NUMERICAL_FEATURES}')
print(f'Feature names: {NUMERICAL_FEATURE_NAMES}')
# Out:
# Features numéricas: 25
# Feature names: ['snapshot_price_yes', 'days_to_end', 'market_age_days_at_snapshot', 'days_since_last_trade', 'history_points_1d', 'history_points_3d', 'history_points_7d', 'history_points_30d', 'history_span_days', 'return_1d', 'return_3d', 'return_7d', 'return_14d', 'return_30d', 'realized_vol_1d', 'realized_vol_3d', 'realized_vol_7d', 'realized_vol_14d', 'realized_vol_30d', 'trend_slope_7d', 'trend_slope_30d', 'price_percentile_30d', 'distance_to_30d_min', 'distance_to_30d_max', 'neg_risk']

# %% [markdown]
# ## 1. Snapshot anti-leakage
#
# El precio final de un mercado resuelto es siempre ~0 o ~1 (post-resolución).
# Usar ese precio como feature es **data leakage** — el modelo vería el resultado antes de predecirlo.
#
# Solución: tomar el precio de la serie temporal **7 días antes del endDate**.

# %%
with open(RAW / 'resolved_markets.json') as f:
    resolved_raw = json.load(f)
with open(RAW / 'price_histories.json') as f:
    price_histories = json.load(f)

print(f'Resueltos: {len(resolved_raw):,}')
print(f'Price histories: {len(price_histories):,}')

# Comparar precio final vs snapshot para una muestra
comparison = []
skipped_comp = {'no_snapshot': 0, 'ambiguous': 0}
for m in resolved_raw[:2000]:
    # Precio post-resolución (contaminado)
    op = m.get('outcomePrices', [])
    if isinstance(op, str):
        try:
            op = json.loads(op)
        except Exception:
            continue
    if not op:
        continue
    price_final = float(op[0])

    # Precio snapshot (7 días antes)
    _, price_snap = build_snapshot_market(
        m,
        price_histories,
        snapshot_offset_days=7,
    )
    if price_snap is None:
        skipped_comp['no_snapshot'] += 1
        continue

    resolution = _infer_resolution_from_market(m)
    if resolution not in ('yes', 'no'):
        skipped_comp['ambiguous'] += 1
        continue

    comparison.append({
        'price_final': price_final,
        'price_snapshot': price_snap,
        'resolved_yes': 1 if resolution == 'yes' else 0,
    })

df_comp = pd.DataFrame(comparison)
print(f'Mercados con snapshot válido: {len(df_comp):,}')
print('  Ignorados en la muestra:')
for k, v in skipped_comp.items():
    print(f'    {k}: {v:,}')
print(f'  Precio final — mean: {df_comp["price_final"].mean():.3f}, std: {df_comp["price_final"].std():.3f}')
print(f'  Price snapshot — mean: {df_comp["price_snapshot"].mean():.3f}, std: {df_comp["price_snapshot"].std():.3f}')
print(f'→ El precio final está concentrado en 0/1 (post-resolución).')
print(f'  → El snapshot tiene rango real (0.05-0.95): útil para el modelo.')
# Out:
# Resueltos: 24,000
# Price histories: 24,900
# Mercados con snapshot válido: 1,954
#   Ignorados en la muestra:
#     no_snapshot: 0
#     ambiguous: 46
#   Precio final — mean: 0.269, std: 0.443
#   Price snapshot — mean: 0.277, std: 0.371
# → El precio final está concentrado en 0/1 (post-resolución).
#   → El snapshot tiene rango real (0.05-0.95): útil para el modelo.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax = axes[0]
ax.hist(df_comp['price_final'], bins=50, color=PALETTE[3], alpha=0.8)
ax.set_title('Precio final (post-resolución)\n← LEAKAGE: siempre 0 o 1')
ax.set_xlabel('price_yes')
ax.set_ylabel('Mercados')

ax = axes[1]
for val, label, color in [(1,'Yes',PALETTE[2]),(0,'No',PALETTE[3])]:
    sub = df_comp[df_comp['resolved_yes']==val]['price_snapshot']
    ax.hist(sub, bins=40, alpha=0.6, label=f'{label} (n={len(sub):,})', color=color, density=True)
ax.set_title('Precio snapshot 7d antes de resolución\n← Esto usamos: precio real en ese momento')
ax.set_xlabel('price_yes (snapshot)')
ax.legend()

plt.suptitle('Snapshot anti-leakage', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig(ROOT / 'figures' / 'fe_snapshot_comparison.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2. Features numéricas — 23 features
#
# Las features se extraen con `extract_numerical_features(market, price_history, order_book)`.
# Para resueltos, el `order_book` siempre es None (CLOB cerrado).

# %%
# Extraer features para muestra con price_history
sample_feats = []
sample_labels = []
skipped_sample = {'no_snapshot': 0, 'ambiguous': 0}

for m in resolved_raw[:3000]:
    mid = str(m.get('id', ''))
    hist = price_histories.get(mid)
    m_snapshot, snap = build_snapshot_market(
        m,
        price_histories,
        snapshot_offset_days=7,
    )
    if m_snapshot is None or snap is None:
        skipped_sample['no_snapshot'] += 1
        continue

    label = compute_label(m, snap)
    if label == -1:
        skipped_sample['ambiguous'] += 1
        continue

    feat = extract_numerical_features(m_snapshot, price_history=hist)
    sample_feats.append(feat)
    sample_labels.append(label)
    if len(sample_feats) >= 1000:
        break

X_sample = np.array(sample_feats)
y_sample = np.array(sample_labels)

print(f'Muestra: {len(X_sample)} mercados')
print(f'  Shape: {X_sample.shape}')
print('  Ignorados en la muestra:')
for k, v in skipped_sample.items():
    print(f'    {k}: {v:,}')
print(f'  Buy:    {y_sample.sum():.0f} ({100*y_sample.mean():.1f}%)')
print(f'  No Buy: {(1-y_sample).sum():.0f} ({100*(1-y_sample).mean():.1f}%)')

# % de ceros por feature
df_feats = pd.DataFrame(X_sample, columns=NUMERICAL_FEATURE_NAMES)
zero_pct = (df_feats == 0).mean() * 100
print(f'Features con >50% ceros (normales para resueltos):')
for name, pct in zero_pct[zero_pct > 50].items():
    print(f'  {name}: {pct:.1f}%')
# Out:
# Muestra: 1000 mercados
#   Shape: (1000, 25)
#   Ignorados en la muestra:
#     no_snapshot: 0
#     ambiguous: 0
#   Buy:    5 (0.5%)
#   No Buy: 995 (99.5%)
# Features con >50% ceros (normales para resueltos):
#   history_points_1d: 100.0%
#   history_points_3d: 100.0%
#   history_points_7d: 100.0%
#   return_1d: 100.0%
#   return_3d: 100.0%
#   return_7d: 100.0%
#   return_14d: 67.7%
#   realized_vol_1d: 100.0%
#   realized_vol_3d: 100.0%
#   realized_vol_7d: 100.0%
#   realized_vol_14d: 66.8%
#   trend_slope_7d: 100.0%
#   distance_to_30d_min: 85.6%

# %%
# AUC-ROC univariado por feature (con snapshot prices)
from sklearn.metrics import roc_auc_score

aucs = {}
for i, name in enumerate(NUMERICAL_FEATURE_NAMES):
    col = X_sample[:, i]
    if col.std() < 1e-8 or len(np.unique(col)) < 2:
        aucs[name] = 0.5
        continue
    try:
        auc = roc_auc_score(y_sample, col)
        aucs[name] = max(auc, 1 - auc)
    except Exception:
        aucs[name] = 0.5

auc_series = pd.Series(aucs).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(8, 8))
colors = ['#C44E52' if v > 0.6 else '#55A868' if v > 0.55 else '#4C72B0' for v in auc_series]
auc_series.plot.barh(ax=ax, color=colors[::-1], alpha=0.85)
ax.axvline(0.5, color='gray', linestyle='--', lw=1.5, label='Random')
ax.axvline(0.55, color='#DD8452', linestyle='--', lw=1)
ax.set_title('AUC-ROC univariado por feature\n(solo con snapshot prices — sin leakage)', fontsize=11)
ax.set_xlabel('AUC-ROC')
ax.legend()
ax.set_xlim(0.45, 0.85)
plt.tight_layout()
plt.savefig(ROOT / 'figures' / 'fe_feature_auc.png', bbox_inches='tight')
plt.show()
print('Top features:')
for name, auc in auc_series.head(8).items():
    print(f'  {name:30s}: {auc:.3f}')
# Out:
# Top features:
#   snapshot_price_yes            : 0.846
#   distance_to_30d_min           : 0.820
#   days_since_last_trade         : 0.815
#   days_to_end                   : 0.804
#   neg_risk                      : 0.803
#   history_span_days             : 0.800
#   return_30d                    : 0.774
#   realized_vol_14d              : 0.751

# %% [markdown]
# ## 3. Encoding categórico
#
# `CategoryEncoder` infiere categoría desde el prefijo del slug.
# Los `events[].tags` de la API de Polymarket siempre llegan vacíos — no son utilizables.

# %%
from collections import Counter
enc = CategoryEncoder()
print(f'Categorías definidas ({len(DEFAULT_CATEGORIES)}): {DEFAULT_CATEGORIES}')
print()

# Distribución sobre los resueltos
cat_ids = enc.encode_batch(resolved_raw)
cat_names = [enc.id_to_cat[c] for c in cat_ids]
counts = Counter(cat_names)

fig, ax = plt.subplots(figsize=(9, 4))
cats = [c for c, _ in counts.most_common()]
vals = [counts[c] for c in cats]
ax.barh(cats, vals, color=PALETTE[0], alpha=0.85)
for i, (c, v) in enumerate(zip(cats, vals)):
    ax.text(v + 50, i, f'{100*v/len(resolved_raw):.1f}%', va='center', fontsize=9)
ax.set_xlabel('Mercados')
ax.set_title(f'Categorías en {len(resolved_raw):,} resueltos (slug-prefix encoding)')
plt.tight_layout()
plt.savefig(ROOT / 'figures' / 'fe_categories.png', bbox_inches='tight')
plt.show()

print('Distribución:')
for cat, cnt in counts.most_common():
    print(f'  {cat:15s}: {cnt:,} ({100*cnt/len(resolved_raw):.1f}%)')
# Out:
# Categorías definidas (10): ['crypto', 'esports', 'sports', 'politics', 'economics', 'technology', 'entertainment', 'health', 'other', 'unknown']
# Distribución:
#   crypto         : 8,266 (34.4%)
#   sports         : 6,592 (27.5%)
#   unknown        : 4,896 (20.4%)
#   esports        : 3,473 (14.5%)
#   technology     : 623 (2.6%)
#   politics       : 88 (0.4%)
#   economics      : 36 (0.1%)
#   entertainment  : 26 (0.1%)

# %% [markdown]
# ## 4. Distribución de labels con snapshot prices
#
# El label es `1` si el mercado resolvió Yes **y** el retorno esperado desde el snapshot ≥ 5%.
# Esto requiere que el precio snapshot sea < 0.952... (para que haya suficiente upside).

# %%
# Analizar distribución completa de labels usando artefactos ya procesados (horizonte 7d)
processed = ROOT / 'data' / 'processed'
required = ['labels.npy', 'snapshot_prices.npy', 'days_to_end.npy', 'market_ids.npy']
missing = [f for f in required if not (processed / f).exists()]
assert not missing, (
    f"Faltan artefactos en {processed}: {missing}\n"
    'Correr primero: python -m src.features.pipeline'
)

days_to_end = np.load(processed / 'days_to_end.npy').astype(int)
mask_7d = days_to_end == 7
assert mask_7d.any(), 'No hay muestras con horizon=7d en data/processed.'

labels_arr = np.load(processed / 'labels.npy')[mask_7d].astype(np.float32)
snaps_arr = np.load(processed / 'snapshot_prices.npy')[mask_7d].astype(float)
market_ids_arr = np.load(processed / 'market_ids.npy', allow_pickle=True)[mask_7d].astype(str)

print('Distribución cargada desde data/processed (horizonte 7d) — sin reconstruir snapshots.')
print(f'Total resueltos raw:      {len(resolved_raw):,}')
print(f'Muestras 7d del pipeline: {len(labels_arr):,}')
print(f'Mercados únicos 7d:       {len(set(market_ids_arr.tolist())):,}')
print('Labels:')
print(f'  Positivos (buy=1):  {labels_arr.sum():.0f} ({100 * labels_arr.mean():.1f}%)')
print(f'  Negativos (buy=0):  {(1 - labels_arr).sum():.0f} ({100 * (1 - labels_arr).mean():.1f}%)')

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax = axes[0]
for val, color, label in [(1, PALETTE[2], 'Buy (1)'), (0, PALETTE[3], 'No Buy (0)')]:
    ax.hist(snaps_arr[labels_arr == val], bins=40, alpha=0.6, color=color, label=label, density=True)
ax.axvline(0.952, color='black', linestyle='--', lw=1.5, label='Umbral retorno 5%')
ax.set_title('Snapshot price por label')
ax.set_xlabel('Precio Yes (7d antes de resolución)')
ax.legend(fontsize=9)

ax = axes[1]
bars = ax.bar(
    ['No Buy (label=0)', 'Buy (label=1)'],
    [(1 - labels_arr).sum(), labels_arr.sum()],
    color=[PALETTE[3], PALETTE[2]],
    alpha=0.85,
    width=0.4,
)
for bar, cnt in zip(bars, [(1 - labels_arr).sum(), labels_arr.sum()]):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 20,
        f'{cnt:.0f} ({100 * cnt / len(labels_arr):.1f}%)',
        ha='center',
    )
ax.set_title('Balance de clases (con snapshot anti-leakage)')
ax.set_ylabel('Muestras 7d')

plt.suptitle('Distribución de labels - snapshot 7 días antes de resolución', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig(ROOT / 'figures' / 'fe_label_distribution.png', bbox_inches='tight')
plt.show()
# Out:
# Distribución cargada desde data/processed (horizonte 7d) — sin reconstruir snapshots.
# Total resueltos raw:      24,000
# Muestras 7d del pipeline: 9,494
# Mercados únicos 7d:       9,494
# Labels:
#   Positivos (buy=1):  3184 (33.5%)
#   Negativos (buy=0):  6310 (66.5%)

# %% [markdown]
# ## 5. Correr el pipeline completo
#
# El notebook hasta aquí es exploratorio. Para generar los datasets reales (`.npy`) usar:
#
# ```bash
# # Genera data/processed/*.npy
# python -m src.features.pipeline
#
# # Con texto real (requiere sentence-transformers, lento):
# python -m src.features.pipeline
#
# # Sin texto real (rápido, para testing):
# python -m src.features.pipeline --dummy-text
#
# # Cambiar snapshot offset (anti-leakage):
# python -m src.features.pipeline --snapshot-offset 14
# ```
#
# El pipeline:
# 1. Carga `resolved_markets.json` + `price_histories.json`
# 2. Para cada resuelto: busca snapshot price 7d antes de resolución
# 3. Descarta mercados sin snapshot o con resolución ambigua
# 4. Extrae 23 features numéricas (con snapshot price inyectado)
# 5. Fit StandardScaler → transforma
# 6. Genera embeddings MiniLM de `question`
# 7. Guarda `.npy` + scaler + category_encoder

# %%
# Verificar output del pipeline (si ya corrió)
processed = ROOT / 'data' / 'processed'
files = ['numerical_features.npy', 'labels.npy', 'category_ids.npy',
         'text_embeddings.npy', 'end_dates.npy']

all_exist = all((processed / f).exists() for f in files)
if all_exist:
    X = np.load(processed / 'numerical_features.npy')
    y = np.load(processed / 'labels.npy')
    print('Pipeline output:')
    print(f'  numerical_features: {X.shape}')
    print(f'  labels:             {y.shape} | {y.sum():.0f} positivos ({100*y.mean():.1f}%)')
    print(f'\n→ Continuar en notebook 03 para EDA del dataset procesado.')
else:
    missing = [f for f in files if not (processed / f).exists()]
    print(f'Pipeline no ha corrido todavía. Faltan: {missing}')
    print('Correr: python -m src.features.pipeline')
# Out:
# Pipeline output:
#   numerical_features: (39545, 25)
#   labels:             (39545,) | 12357 positivos (31.2%)
#
# → Continuar en notebook 03 para EDA del dataset procesado.
